# %% [markdown]
# # Phoneme Classifier Testing: Noisy
# ### Author: Cathal Ó Faoláin
# ### 15:51, 02/08/2024
#
# The goal of this work is to understand how we can use predicted IHC potentials, such as those predicted by WavIHC, introduced in the paper "WaveNet-based approximation of a cochlear filtering and hair cell transduction model".  Feature encoders designed to use these predicted IHC potentials are evaluated against other state-of-the-art feature encoders in order to understand how discriminating they are, and over a range of different Signal-to-Noise Ratios (SNRs).
#
# This notebook tests the feature encoders we shall evaluate. We have 12 feature encoders:
#
# - Contrastive Predictive Coding (CPC)
# - CPC-80
# - Wav2vec2.0
# - Wav2vec2.0-80
# - Autoregressive Predictive Coding (APC)
# - IHC CPC
# - IHC CPC 80
# - IHC Wav2vec2
# - IHC Wav2vec2 80
# - IHC Extract
# - IHC Extract 512
# - IHC Extract 2
#
# The first three feature encoders, CPC, Wav2vec2.0 and APC are based on the designs used in each of the papers. Any context encoders that tries to model longer-term dependencies have been removed - so no transformers or Recurrent Neural Networks (RNN). This is to allow for us to evaluate how discriminating the features themselves are.
#
# IHC CPC and Wav2vec2 are adapted feature encoders that take predicted IHC potentials as input rather than the signal alone. Each is inspired by their namesake models.
#
# The testing here is over an SNR range of -10dB to 30dB. There are two main classes of noise added - amplitude modulated and steady. The types of additive noise is:
# - White Noise (Steady)
#
# This should give us a good indication of how well our new features are able to separate speech information from a noisy environment or background.

# %% [markdown]
# ## Imports

# %%
import torch
from torch import nn
import librosa
import time
from torch.nn.utils.rnn import pad_packed_sequence, pack_padded_sequence
from torch.utils.data import DataLoader, Dataset, IterableDataset
import torchaudio
import pandas as pd
import numpy as np
import time
import sys
import yaml
import math
import scipy.signal as signal
from dataclasses import dataclass, field
from typing import List, Tuple
import torch.nn.functional as F
from pathlib import Path
import pickle

# %%
sys.path.append('./IHCApproxNH/')
from classes import WaveNet
from utils import utils
from Encoders import FeatureEncoders 
from TIMIT_utils import TIMIT_utils
from Train_TestFunctions import TrainEvalFunctions

# %% [markdown]
# ## Set Global Variables

# %%
#And save location 
dir_results=Path('Results/Noisy')
dir_results.mkdir(parents=True, exist_ok=True)

#Noise variables
SNRs=[30, 25, 20, 15, 10, 5, 0, -5, -10]
noise_types=['White', 'air_conditioner', 'dog_bark', 'street_music', 'children_playing']

# %% [markdown]
# ## Noise Test : Fully Trained Clean Models
#
# This sections tests models trained on the full clean dataset, and evaluated in their training on the validation dataset. These models have never been exposed to noise in their training, and gives us their overall performance. Both original (signal or mel spectrogram input) models and IHC-input models are tested here over the range of SNRs provided and over all the different noise types.
#
# ### Original Models testing

# %%
#original_models=[ "MelSimple_MLP", "MelSimple", "Wav2vec2", "Wav2vec2_80", "CPC_80", "CPC",  "SIG_Extract", "SIG_Extract_512", "SIG_Extract_2.0", "Whisper", "Whisper_80", "SIG_Extract_3.0"]

original_models=["Whisper", "Whisper_80", "SIG_Extract_3.0"]

for noise in noise_types:

    dir_snr = Path("./Results/Noisy/{}".format(noise))
    dir_snr.mkdir(parents=True, exist_ok=True)
    print("Making Directory: %s" % dir_snr)
    
    for snr in SNRs:
        dir_snr = Path("./Results/Noisy/{}/{}".format(noise, snr))
        dir_snr.mkdir(parents=True, exist_ok=True)
        print("Making Directory: %s" % dir_snr)
        
        test_accuracies={}

        #Reload any old results so that we can continue training if required
        test_location='Results/Noisy/{}/{}/original_models.pkl'.format(noise, snr)
        if(Path(test_location).is_file()):
            with open(test_location, 'rb') as f:
                test_accuracies = pickle.load(f)
            
        for model in original_models:
            print("=============================")
            print("Starting Noisy Testing for: %s for %s noise at an SNR of %d" %(model, noise, snr))
            
            #Test the model on the noisy dataset
            test_accu, test_loss, unique_phonemes, time=TrainEvalFunctions.test_best(model, distributed=False,  noise=True , noise_type= noise, SNR= snr)

            test_accuracies["{}-Clean".format(model)]=test_accu

            print("==============================")
            print("")
            print("")

        with open(test_location, 'wb') as f:
            pickle.dump(test_accuracies, f)
# Out:
# Making Directory: Results/Noisy/White
# Making Directory: Results/Noisy/White/30
# =============================
# Starting Noisy Testing for: Whisper for White noise at an SNR of 30
# > Initialising model: Whisper
# **************************************************************
# Testing Best Model found at: Model Checkpoints/Whisper Checkpoints/best_Whisper_checkpoint.pth.tar
# **************************************************************
# > Initialising model: Whisper
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 40
# Evaluation accuracy:  0.5575, Phoneme Error Rate:  0.4425, Loss :  0.8816, Time:  16.0137s, Time per sample:  0.4003s
# +---------------------------------------------+
# ==============================
#
#
# =============================
# Starting Noisy Testing for: Whisper_80 for White noise at an SNR of 30
# > Initialising model: Whisper_80
# **************************************************************
# Testing Best Model found at: Model Checkpoints/Whisper_80 Checkpoints/best_Whisper_80_checkpoint.pth.tar
# **************************************************************
# > Initialising model: Whisper_80
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 40
# Evaluation accuracy:  0.5468, Phoneme Error Rate:  0.4532, Loss :  0.8851, Time:  15.4247s, Time per sample:  0.3856s
# +---------------------------------------------+
# ==============================
#
#
# =============================
# Starting Noisy Testing for: SIG_Extract_3.0 for White noise at an SNR of 30
# > Initialising model: SIG_Extract_3.0
# **************************************************************
# Testing Best Model found at: Model Checkpoints/SIG_Extract_3.0 Checkpoints/best_SIG_Extract_3.0_checkpoint.pth.tar
# **************************************************************
# > Initialising model: SIG_Extract_3.0
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 237
# Evaluation accuracy:  0.4965, Phoneme Error Rate:  0.5035, Loss :  1.3021, Time:  9.8956s, Time per sample:  0.0418s
# +---------------------------------------------+
# ==============================
#
#
# Making Directory: Results/Noisy/White/25
# =============================
# Starting Noisy Testing for: Whisper for White noise at an SNR of 25
# > Initialising model: Whisper
# **************************************************************
# Testing Best Model found at: Model Checkpoints/Whisper Checkpoints/best_Whisper_checkpoint.pth.tar
# **************************************************************
# > Initialising model: Whisper
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 40
# Evaluation accuracy:  0.4518, Phoneme Error Rate:  0.5482, Loss :  1.1592, Time:  15.1621s, Time per sample:  0.3791s
# +---------------------------------------------+
# ==============================
#
#
# =============================
# Starting Noisy Testing for: Whisper_80 for White noise at an SNR of 25
# > Initialising model: Whisper_80
# **************************************************************
# Testing Best Model found at: Model Checkpoints/Whisper_80 Checkpoints/best_Whisper_80_checkpoint.pth.tar
# **************************************************************
# > Initialising model: Whisper_80
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 40
# Evaluation accuracy:  0.4306, Phoneme Error Rate:  0.5694, Loss :  1.1635, Time:  15.1700s, Time per sample:  0.3793s
# +---------------------------------------------+
# ==============================
#
#
# =============================
# Starting Noisy Testing for: SIG_Extract_3.0 for White noise at an SNR of 25
# > Initialising model: SIG_Extract_3.0
# **************************************************************
# Testing Best Model found at: Model Checkpoints/SIG_Extract_3.0 Checkpoints/best_SIG_Extract_3.0_checkpoint.pth.tar
# **************************************************************
# > Initialising model: SIG_Extract_3.0
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 237
# Evaluation accuracy:  0.3150, Phoneme Error Rate:  0.6850, Loss :  1.6456, Time:  10.1423s, Time per sample:  0.0428s
# +---------------------------------------------+
# ==============================
#
#
# Making Directory: Results/Noisy/White/20
# =============================
# Starting Noisy Testing for: Whisper for White noise at an SNR of 20
# > Initialising model: Whisper
# **************************************************************
# Testing Best Model found at: Model Checkpoints/Whisper Checkpoints/best_Whisper_checkpoint.pth.tar
# **************************************************************
# > Initialising model: Whisper
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 40
# Evaluation accuracy:  0.3695, Phoneme Error Rate:  0.6305, Loss :  1.5904, Time:  15.2784s, Time per sample:  0.3820s
# +---------------------------------------------+
# ==============================
#
#
# =============================
# Starting Noisy Testing for: Whisper_80 for White noise at an SNR of 20
# > Initialising model: Whisper_80
# **************************************************************
# Testing Best Model found at: Model Checkpoints/Whisper_80 Checkpoints/best_Whisper_80_checkpoint.pth.tar
# **************************************************************
# > Initialising model: Whisper_80
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 40
# Evaluation accuracy:  0.3434, Phoneme Error Rate:  0.6566, Loss :  1.5949, Time:  15.4034s, Time per sample:  0.3851s
# +---------------------------------------------+
# ==============================
#
#
# =============================
# Starting Noisy Testing for: SIG_Extract_3.0 for White noise at an SNR of 20
# > Initialising model: SIG_Extract_3.0
# **************************************************************
# Testing Best Model found at: Model Checkpoints/SIG_Extract_3.0 Checkpoints/best_SIG_Extract_3.0_checkpoint.pth.tar
# **************************************************************
# > Initialising model: SIG_Extract_3.0
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 237
# Evaluation accuracy:  0.2786, Phoneme Error Rate:  0.7214, Loss :  2.0086, Time:  10.0552s, Time per sample:  0.0424s
# +---------------------------------------------+
# ==============================
#
#
# Making Directory: Results/Noisy/White/15
# =============================
# Starting Noisy Testing for: Whisper for White noise at an SNR of 15
# > Initialising model: Whisper
# **************************************************************
# Testing Best Model found at: Model Checkpoints/Whisper Checkpoints/best_Whisper_checkpoint.pth.tar
# **************************************************************
# > Initialising model: Whisper
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 40
# Evaluation accuracy:  0.3070, Phoneme Error Rate:  0.6930, Loss :  2.0608, Time:  15.2982s, Time per sample:  0.3825s
# +---------------------------------------------+
# ==============================
#
#
# =============================
# Starting Noisy Testing for: Whisper_80 for White noise at an SNR of 15
# > Initialising model: Whisper_80
# **************************************************************
# Testing Best Model found at: Model Checkpoints/Whisper_80 Checkpoints/best_Whisper_80_checkpoint.pth.tar
# **************************************************************
# > Initialising model: Whisper_80
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 40
# Evaluation accuracy:  0.2786, Phoneme Error Rate:  0.7214, Loss :  2.0487, Time:  15.3375s, Time per sample:  0.3834s
# +---------------------------------------------+
# ==============================
#
#
# =============================
# Starting Noisy Testing for: SIG_Extract_3.0 for White noise at an SNR of 15
# > Initialising model: SIG_Extract_3.0
# **************************************************************
# Testing Best Model found at: Model Checkpoints/SIG_Extract_3.0 Checkpoints/best_SIG_Extract_3.0_checkpoint.pth.tar
# **************************************************************
# > Initialising model: SIG_Extract_3.0
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 237
# Evaluation accuracy:  0.2477, Phoneme Error Rate:  0.7523, Loss :  2.2698, Time:  10.1436s, Time per sample:  0.0428s
# +---------------------------------------------+
# ==============================
#
#
# Making Directory: Results/Noisy/White/10
# =============================
# Starting Noisy Testing for: Whisper for White noise at an SNR of 10
# > Initialising model: Whisper
# **************************************************************
# Testing Best Model found at: Model Checkpoints/Whisper Checkpoints/best_Whisper_checkpoint.pth.tar
# **************************************************************
# > Initialising model: Whisper
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 40
# Evaluation accuracy:  0.2476, Phoneme Error Rate:  0.7524, Loss :  2.5595, Time:  15.3154s, Time per sample:  0.3829s
# +---------------------------------------------+
# ==============================
#
#
# =============================
# Starting Noisy Testing for: Whisper_80 for White noise at an SNR of 10
# > Initialising model: Whisper_80
# **************************************************************
# Testing Best Model found at: Model Checkpoints/Whisper_80 Checkpoints/best_Whisper_80_checkpoint.pth.tar
# **************************************************************
# > Initialising model: Whisper_80
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 40
# Evaluation accuracy:  0.2158, Phoneme Error Rate:  0.7842, Loss :  2.5218, Time:  15.3365s, Time per sample:  0.3834s
# +---------------------------------------------+
# ==============================
#
#
# =============================
# Starting Noisy Testing for: SIG_Extract_3.0 for White noise at an SNR of 10
# > Initialising model: SIG_Extract_3.0
# **************************************************************
# Testing Best Model found at: Model Checkpoints/SIG_Extract_3.0 Checkpoints/best_SIG_Extract_3.0_checkpoint.pth.tar
# **************************************************************
# > Initialising model: SIG_Extract_3.0
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 237
# Evaluation accuracy:  0.2063, Phoneme Error Rate:  0.7937, Loss :  2.5405, Time:  10.0530s, Time per sample:  0.0424s
# +---------------------------------------------+
# ==============================
#
#
# Making Directory: Results/Noisy/White/5
# =============================
# Starting Noisy Testing for: Whisper for White noise at an SNR of 5
# > Initialising model: Whisper
# **************************************************************
# Testing Best Model found at: Model Checkpoints/Whisper Checkpoints/best_Whisper_checkpoint.pth.tar
# **************************************************************
# > Initialising model: Whisper
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 40
# Evaluation accuracy:  0.1795, Phoneme Error Rate:  0.8205, Loss :  3.1228, Time:  15.3391s, Time per sample:  0.3835s
# +---------------------------------------------+
# ==============================
#
#
# =============================
# Starting Noisy Testing for: Whisper_80 for White noise at an SNR of 5
# > Initialising model: Whisper_80
# **************************************************************
# Testing Best Model found at: Model Checkpoints/Whisper_80 Checkpoints/best_Whisper_80_checkpoint.pth.tar
# **************************************************************
# > Initialising model: Whisper_80
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 40
# Evaluation accuracy:  0.1467, Phoneme Error Rate:  0.8533, Loss :  3.4693, Time:  15.3551s, Time per sample:  0.3839s
# +---------------------------------------------+
# ==============================
#
#
# =============================
# Starting Noisy Testing for: SIG_Extract_3.0 for White noise at an SNR of 5
# > Initialising model: SIG_Extract_3.0
# **************************************************************
# Testing Best Model found at: Model Checkpoints/SIG_Extract_3.0 Checkpoints/best_SIG_Extract_3.0_checkpoint.pth.tar
# **************************************************************
# > Initialising model: SIG_Extract_3.0
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 237
# Evaluation accuracy:  0.1631, Phoneme Error Rate:  0.8369, Loss :  2.8011, Time:  10.3146s, Time per sample:  0.0435s
# +---------------------------------------------+
# ==============================
#
#
# Making Directory: Results/Noisy/White/0
# =============================
# Starting Noisy Testing for: Whisper for White noise at an SNR of 0
# > Initialising model: Whisper
# **************************************************************
# Testing Best Model found at: Model Checkpoints/Whisper Checkpoints/best_Whisper_checkpoint.pth.tar
# **************************************************************
# > Initialising model: Whisper
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 40
# Evaluation accuracy:  0.1206, Phoneme Error Rate:  0.8794, Loss :  3.8572, Time:  15.3216s, Time per sample:  0.3830s
# +---------------------------------------------+
# ==============================
#
#
# =============================
# Starting Noisy Testing for: Whisper_80 for White noise at an SNR of 0
# > Initialising model: Whisper_80
# **************************************************************
# Testing Best Model found at: Model Checkpoints/Whisper_80 Checkpoints/best_Whisper_80_checkpoint.pth.tar
# **************************************************************
# > Initialising model: Whisper_80
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 40
# Evaluation accuracy:  0.0827, Phoneme Error Rate:  0.9173, Loss :  5.1260, Time:  15.3462s, Time per sample:  0.3837s
# +---------------------------------------------+
# ==============================
#
#
# =============================
# Starting Noisy Testing for: SIG_Extract_3.0 for White noise at an SNR of 0
# > Initialising model: SIG_Extract_3.0
# **************************************************************
# Testing Best Model found at: Model Checkpoints/SIG_Extract_3.0 Checkpoints/best_SIG_Extract_3.0_checkpoint.pth.tar
# **************************************************************
# > Initialising model: SIG_Extract_3.0
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 237
# Evaluation accuracy:  0.1219, Phoneme Error Rate:  0.8781, Loss :  3.0737, Time:  10.2609s, Time per sample:  0.0433s
# +---------------------------------------------+
# ==============================
#
#
# Making Directory: Results/Noisy/White/-5
# =============================
# Starting Noisy Testing for: Whisper for White noise at an SNR of -5
# > Initialising model: Whisper
# **************************************************************
# Testing Best Model found at: Model Checkpoints/Whisper Checkpoints/best_Whisper_checkpoint.pth.tar
# **************************************************************
# > Initialising model: Whisper
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 40
# Evaluation accuracy:  0.0801, Phoneme Error Rate:  0.9199, Loss :  7.9646, Time:  15.4210s, Time per sample:  0.3855s
# +---------------------------------------------+
# ==============================
#
#
# =============================
# Starting Noisy Testing for: Whisper_80 for White noise at an SNR of -5
# > Initialising model: Whisper_80
# **************************************************************
# Testing Best Model found at: Model Checkpoints/Whisper_80 Checkpoints/best_Whisper_80_checkpoint.pth.tar
# **************************************************************
# > Initialising model: Whisper_80
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 40
# Evaluation accuracy:  0.0539, Phoneme Error Rate:  0.9461, Loss :  6.5440, Time:  15.4330s, Time per sample:  0.3858s
# +---------------------------------------------+
# ==============================
#
#
# =============================
# Starting Noisy Testing for: SIG_Extract_3.0 for White noise at an SNR of -5
# > Initialising model: SIG_Extract_3.0
# **************************************************************
# Testing Best Model found at: Model Checkpoints/SIG_Extract_3.0 Checkpoints/best_SIG_Extract_3.0_checkpoint.pth.tar
# **************************************************************
# > Initialising model: SIG_Extract_3.0
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 237
# Evaluation accuracy:  0.0869, Phoneme Error Rate:  0.9131, Loss :  3.3719, Time:  10.3474s, Time per sample:  0.0437s
# +---------------------------------------------+
# ==============================
#
#
# Making Directory: Results/Noisy/White/-10
# =============================
# Starting Noisy Testing for: Whisper for White noise at an SNR of -10
# > Initialising model: Whisper
# **************************************************************
# Testing Best Model found at: Model Checkpoints/Whisper Checkpoints/best_Whisper_checkpoint.pth.tar
# **************************************************************
# > Initialising model: Whisper
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 40
# Evaluation accuracy:  0.0470, Phoneme Error Rate:  0.9530, Loss :  27.7064, Time:  15.4444s, Time per sample:  0.3861s
# +---------------------------------------------+
# ==============================
#
#
# =============================
# Starting Noisy Testing for: Whisper_80 for White noise at an SNR of -10
# > Initialising model: Whisper_80
# **************************************************************
# Testing Best Model found at: Model Checkpoints/Whisper_80 Checkpoints/best_Whisper_80_checkpoint.pth.tar
# **************************************************************
# > Initialising model: Whisper_80
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 40
# Evaluation accuracy:  0.0622, Phoneme Error Rate:  0.9378, Loss :  9.6672, Time:  15.2039s, Time per sample:  0.3801s
# +---------------------------------------------+
# ==============================
#
#
# =============================
# Starting Noisy Testing for: SIG_Extract_3.0 for White noise at an SNR of -10
# > Initialising model: SIG_Extract_3.0
# **************************************************************
# Testing Best Model found at: Model Checkpoints/SIG_Extract_3.0 Checkpoints/best_SIG_Extract_3.0_checkpoint.pth.tar
# **************************************************************
# > Initialising model: SIG_Extract_3.0
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 237
# Evaluation accuracy:  0.0603, Phoneme Error Rate:  0.9397, Loss :  3.6904, Time:  10.3364s, Time per sample:  0.0436s
# +---------------------------------------------+
# ==============================
#
#
# Making Directory: Results/Noisy/air_conditioner
# Making Directory: Results/Noisy/air_conditioner/30
# =============================
# Starting Noisy Testing for: Whisper for air_conditioner noise at an SNR of 30
# > Initialising model: Whisper
# **************************************************************
# Testing Best Model found at: Model Checkpoints/Whisper Checkpoints/best_Whisper_checkpoint.pth.tar
# **************************************************************
# > Initialising model: Whisper
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 40
# Evaluation accuracy:  0.6216, Phoneme Error Rate:  0.3784, Loss :  0.8023, Time:  14.7558s, Time per sample:  0.3689s
# +---------------------------------------------+
# ==============================
#
#
# =============================
# Starting Noisy Testing for: Whisper_80 for air_conditioner noise at an SNR of 30
# > Initialising model: Whisper_80
# **************************************************************
# Testing Best Model found at: Model Checkpoints/Whisper_80 Checkpoints/best_Whisper_80_checkpoint.pth.tar
# **************************************************************
# > Initialising model: Whisper_80
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 40
# Evaluation accuracy:  0.6061, Phoneme Error Rate:  0.3939, Loss :  0.8039, Time:  14.7502s, Time per sample:  0.3688s
# +---------------------------------------------+
# ==============================
#
#
# =============================
# Starting Noisy Testing for: SIG_Extract_3.0 for air_conditioner noise at an SNR of 30
# > Initialising model: SIG_Extract_3.0
# **************************************************************
# Testing Best Model found at: Model Checkpoints/SIG_Extract_3.0 Checkpoints/best_SIG_Extract_3.0_checkpoint.pth.tar
# **************************************************************
# > Initialising model: SIG_Extract_3.0
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 237
# Evaluation accuracy:  0.5570, Phoneme Error Rate:  0.4430, Loss :  1.1658, Time:  9.8853s, Time per sample:  0.0417s
# +---------------------------------------------+
# ==============================
#
#
# Making Directory: Results/Noisy/air_conditioner/25
# =============================
# Starting Noisy Testing for: Whisper for air_conditioner noise at an SNR of 25
# > Initialising model: Whisper
# **************************************************************
# Testing Best Model found at: Model Checkpoints/Whisper Checkpoints/best_Whisper_checkpoint.pth.tar
# **************************************************************
# > Initialising model: Whisper
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 40
# Evaluation accuracy:  0.5740, Phoneme Error Rate:  0.4260, Loss :  0.9891, Time:  14.7960s, Time per sample:  0.3699s
# +---------------------------------------------+
# ==============================
#
#
# =============================
# Starting Noisy Testing for: Whisper_80 for air_conditioner noise at an SNR of 25
# > Initialising model: Whisper_80
# **************************************************************
# Testing Best Model found at: Model Checkpoints/Whisper_80 Checkpoints/best_Whisper_80_checkpoint.pth.tar
# **************************************************************
# > Initialising model: Whisper_80
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 40
# Evaluation accuracy:  0.5577, Phoneme Error Rate:  0.4423, Loss :  0.9595, Time:  14.8078s, Time per sample:  0.3702s
# +---------------------------------------------+
# ==============================
#
#
# =============================
# Starting Noisy Testing for: SIG_Extract_3.0 for air_conditioner noise at an SNR of 25
# > Initialising model: SIG_Extract_3.0
# **************************************************************
# Testing Best Model found at: Model Checkpoints/SIG_Extract_3.0 Checkpoints/best_SIG_Extract_3.0_checkpoint.pth.tar
# **************************************************************
# > Initialising model: SIG_Extract_3.0
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 237
# Evaluation accuracy:  0.5408, Phoneme Error Rate:  0.4592, Loss :  1.2360, Time:  9.6971s, Time per sample:  0.0409s
# +---------------------------------------------+
# ==============================
#
#
# Making Directory: Results/Noisy/air_conditioner/20
# =============================
# Starting Noisy Testing for: Whisper for air_conditioner noise at an SNR of 20
# > Initialising model: Whisper
# **************************************************************
# Testing Best Model found at: Model Checkpoints/Whisper Checkpoints/best_Whisper_checkpoint.pth.tar
# **************************************************************
# > Initialising model: Whisper
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 40
# Evaluation accuracy:  0.4781, Phoneme Error Rate:  0.5219, Loss :  1.6168, Time:  14.8104s, Time per sample:  0.3703s
# +---------------------------------------------+
# ==============================
#
#
# =============================
# Starting Noisy Testing for: Whisper_80 for air_conditioner noise at an SNR of 20
# > Initialising model: Whisper_80
# **************************************************************
# Testing Best Model found at: Model Checkpoints/Whisper_80 Checkpoints/best_Whisper_80_checkpoint.pth.tar
# **************************************************************
# > Initialising model: Whisper_80
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 40
# Evaluation accuracy:  0.4558, Phoneme Error Rate:  0.5442, Loss :  1.4510, Time:  14.8249s, Time per sample:  0.3706s
# +---------------------------------------------+
# ==============================
#
#
# =============================
# Starting Noisy Testing for: SIG_Extract_3.0 for air_conditioner noise at an SNR of 20
# > Initialising model: SIG_Extract_3.0
# **************************************************************
# Testing Best Model found at: Model Checkpoints/SIG_Extract_3.0 Checkpoints/best_SIG_Extract_3.0_checkpoint.pth.tar
# **************************************************************
# > Initialising model: SIG_Extract_3.0
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 237
# Evaluation accuracy:  0.4814, Phoneme Error Rate:  0.5186, Loss :  1.4312, Time:  9.7706s, Time per sample:  0.0412s
# +---------------------------------------------+
# ==============================
#
#
# Making Directory: Results/Noisy/air_conditioner/15
# =============================
# Starting Noisy Testing for: Whisper for air_conditioner noise at an SNR of 15
# > Initialising model: Whisper
# **************************************************************
# Testing Best Model found at: Model Checkpoints/Whisper Checkpoints/best_Whisper_checkpoint.pth.tar
# **************************************************************
# > Initialising model: Whisper
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 40
# Evaluation accuracy:  0.3478, Phoneme Error Rate:  0.6522, Loss :  3.7389, Time:  14.9229s, Time per sample:  0.3731s
# +---------------------------------------------+
# ==============================
#
#
# =============================
# Starting Noisy Testing for: Whisper_80 for air_conditioner noise at an SNR of 15
# > Initialising model: Whisper_80
# **************************************************************
# Testing Best Model found at: Model Checkpoints/Whisper_80 Checkpoints/best_Whisper_80_checkpoint.pth.tar
# **************************************************************
# > Initialising model: Whisper_80
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 40
# Evaluation accuracy:  0.3131, Phoneme Error Rate:  0.6869, Loss :  2.9822, Time:  14.9643s, Time per sample:  0.3741s
# +---------------------------------------------+
# ==============================
#
#
# =============================
# Starting Noisy Testing for: SIG_Extract_3.0 for air_conditioner noise at an SNR of 15
# > Initialising model: SIG_Extract_3.0
# **************************************************************
# Testing Best Model found at: Model Checkpoints/SIG_Extract_3.0 Checkpoints/best_SIG_Extract_3.0_checkpoint.pth.tar
# **************************************************************
# > Initialising model: SIG_Extract_3.0
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 237
# Evaluation accuracy:  0.3510, Phoneme Error Rate:  0.6490, Loss :  1.9331, Time:  9.9691s, Time per sample:  0.0421s
# +---------------------------------------------+
# ==============================
#
#
# Making Directory: Results/Noisy/air_conditioner/10
# =============================
# Starting Noisy Testing for: Whisper for air_conditioner noise at an SNR of 10
# > Initialising model: Whisper
# **************************************************************
# Testing Best Model found at: Model Checkpoints/Whisper Checkpoints/best_Whisper_checkpoint.pth.tar
# **************************************************************
# > Initialising model: Whisper
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 40
# Evaluation accuracy:  0.2200, Phoneme Error Rate:  0.7800, Loss :  12.2886, Time:  14.9685s, Time per sample:  0.3742s
# +---------------------------------------------+
# ==============================
#
#
# =============================
# Starting Noisy Testing for: Whisper_80 for air_conditioner noise at an SNR of 10
# > Initialising model: Whisper_80
# **************************************************************
# Testing Best Model found at: Model Checkpoints/Whisper_80 Checkpoints/best_Whisper_80_checkpoint.pth.tar
# **************************************************************
# > Initialising model: Whisper_80
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 40
# Evaluation accuracy:  0.1847, Phoneme Error Rate:  0.8153, Loss :  8.4224, Time:  14.9452s, Time per sample:  0.3736s
# +---------------------------------------------+
# ==============================
#
#
# =============================
# Starting Noisy Testing for: SIG_Extract_3.0 for air_conditioner noise at an SNR of 10
# > Initialising model: SIG_Extract_3.0
# **************************************************************
# Testing Best Model found at: Model Checkpoints/SIG_Extract_3.0 Checkpoints/best_SIG_Extract_3.0_checkpoint.pth.tar
# **************************************************************
# > Initialising model: SIG_Extract_3.0
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 237
# Evaluation accuracy:  0.2247, Phoneme Error Rate:  0.7753, Loss :  2.8778, Time:  10.0707s, Time per sample:  0.0425s
# +---------------------------------------------+
# ==============================
#
#
# Making Directory: Results/Noisy/air_conditioner/5
# =============================
# Starting Noisy Testing for: Whisper for air_conditioner noise at an SNR of 5
# > Initialising model: Whisper
# **************************************************************
# Testing Best Model found at: Model Checkpoints/Whisper Checkpoints/best_Whisper_checkpoint.pth.tar
# **************************************************************
# > Initialising model: Whisper
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 40
# Evaluation accuracy:  0.1273, Phoneme Error Rate:  0.8727, Loss :  48.6704, Time:  15.1565s, Time per sample:  0.3789s
# +---------------------------------------------+
# ==============================
#
#
# =============================
# Starting Noisy Testing for: Whisper_80 for air_conditioner noise at an SNR of 5
# > Initialising model: Whisper_80
# **************************************************************
# Testing Best Model found at: Model Checkpoints/Whisper_80 Checkpoints/best_Whisper_80_checkpoint.pth.tar
# **************************************************************
# > Initialising model: Whisper_80
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 40
# Evaluation accuracy:  0.0997, Phoneme Error Rate:  0.9003, Loss :  28.5573, Time:  15.3690s, Time per sample:  0.3842s
# +---------------------------------------------+
# ==============================
#
#
# =============================
# Starting Noisy Testing for: SIG_Extract_3.0 for air_conditioner noise at an SNR of 5
# > Initialising model: SIG_Extract_3.0
# **************************************************************
# Testing Best Model found at: Model Checkpoints/SIG_Extract_3.0 Checkpoints/best_SIG_Extract_3.0_checkpoint.pth.tar
# **************************************************************
# > Initialising model: SIG_Extract_3.0
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 237
# Evaluation accuracy:  0.1477, Phoneme Error Rate:  0.8523, Loss :  3.9874, Time:  10.1837s, Time per sample:  0.0430s
# +---------------------------------------------+
# ==============================
#
#
# Making Directory: Results/Noisy/air_conditioner/0
# =============================
# Starting Noisy Testing for: Whisper for air_conditioner noise at an SNR of 0
# > Initialising model: Whisper
# **************************************************************
# Testing Best Model found at: Model Checkpoints/Whisper Checkpoints/best_Whisper_checkpoint.pth.tar
# **************************************************************
# > Initialising model: Whisper
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 40
# Evaluation accuracy:  0.0758, Phoneme Error Rate:  0.9242, Loss :  191.2885, Time:  15.0669s, Time per sample:  0.3767s
# +---------------------------------------------+
# ==============================
#
#
# =============================
# Starting Noisy Testing for: Whisper_80 for air_conditioner noise at an SNR of 0
# > Initialising model: Whisper_80
# **************************************************************
# Testing Best Model found at: Model Checkpoints/Whisper_80 Checkpoints/best_Whisper_80_checkpoint.pth.tar
# **************************************************************
# > Initialising model: Whisper_80
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 40
# Evaluation accuracy:  0.0556, Phoneme Error Rate:  0.9444, Loss :  98.8771, Time:  15.0787s, Time per sample:  0.3770s
# +---------------------------------------------+
# ==============================
#
#
# =============================
# Starting Noisy Testing for: SIG_Extract_3.0 for air_conditioner noise at an SNR of 0
# > Initialising model: SIG_Extract_3.0
# **************************************************************
# Testing Best Model found at: Model Checkpoints/SIG_Extract_3.0 Checkpoints/best_SIG_Extract_3.0_checkpoint.pth.tar
# **************************************************************
# > Initialising model: SIG_Extract_3.0
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 237
# Evaluation accuracy:  0.0937, Phoneme Error Rate:  0.9063, Loss :  4.9990, Time:  10.3908s, Time per sample:  0.0438s
# +---------------------------------------------+
# ==============================
#
#
# Making Directory: Results/Noisy/air_conditioner/-5
# =============================
# Starting Noisy Testing for: Whisper for air_conditioner noise at an SNR of -5
# > Initialising model: Whisper
# **************************************************************
# Testing Best Model found at: Model Checkpoints/Whisper Checkpoints/best_Whisper_checkpoint.pth.tar
# **************************************************************
# > Initialising model: Whisper
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 40
# Evaluation accuracy:  0.0541, Phoneme Error Rate:  0.9459, Loss :  698.9445, Time:  15.1234s, Time per sample:  0.3781s
# +---------------------------------------------+
# ==============================
#
#
# =============================
# Starting Noisy Testing for: Whisper_80 for air_conditioner noise at an SNR of -5
# > Initialising model: Whisper_80
# **************************************************************
# Testing Best Model found at: Model Checkpoints/Whisper_80 Checkpoints/best_Whisper_80_checkpoint.pth.tar
# **************************************************************
# > Initialising model: Whisper_80
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 40
# Evaluation accuracy:  0.0376, Phoneme Error Rate:  0.9624, Loss :  331.9801, Time:  15.1411s, Time per sample:  0.3785s
# +---------------------------------------------+
# ==============================
#
#
# =============================
# Starting Noisy Testing for: SIG_Extract_3.0 for air_conditioner noise at an SNR of -5
# > Initialising model: SIG_Extract_3.0
# **************************************************************
# Testing Best Model found at: Model Checkpoints/SIG_Extract_3.0 Checkpoints/best_SIG_Extract_3.0_checkpoint.pth.tar
# **************************************************************
# > Initialising model: SIG_Extract_3.0
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 237
# Evaluation accuracy:  0.0568, Phoneme Error Rate:  0.9432, Loss :  5.9358, Time:  10.5099s, Time per sample:  0.0443s
# +---------------------------------------------+
# ==============================
#
#
# Making Directory: Results/Noisy/air_conditioner/-10
# =============================
# Starting Noisy Testing for: Whisper for air_conditioner noise at an SNR of -10
# > Initialising model: Whisper
# **************************************************************
# Testing Best Model found at: Model Checkpoints/Whisper Checkpoints/best_Whisper_checkpoint.pth.tar
# **************************************************************
# > Initialising model: Whisper
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 40
# Evaluation accuracy:  0.0456, Phoneme Error Rate:  0.9544, Loss :  2400.8517, Time:  15.0713s, Time per sample:  0.3768s
# +---------------------------------------------+
# ==============================
#
#
# =============================
# Starting Noisy Testing for: Whisper_80 for air_conditioner noise at an SNR of -10
# > Initialising model: Whisper_80
# **************************************************************
# Testing Best Model found at: Model Checkpoints/Whisper_80 Checkpoints/best_Whisper_80_checkpoint.pth.tar
# **************************************************************
# > Initialising model: Whisper_80
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 40
# Evaluation accuracy:  0.0321, Phoneme Error Rate:  0.9679, Loss :  1080.2015, Time:  15.0825s, Time per sample:  0.3771s
# +---------------------------------------------+
# ==============================
#
#
# =============================
# Starting Noisy Testing for: SIG_Extract_3.0 for air_conditioner noise at an SNR of -10
# > Initialising model: SIG_Extract_3.0
# **************************************************************
# Testing Best Model found at: Model Checkpoints/SIG_Extract_3.0 Checkpoints/best_SIG_Extract_3.0_checkpoint.pth.tar
# **************************************************************
# > Initialising model: SIG_Extract_3.0
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 237
# Evaluation accuracy:  0.0378, Phoneme Error Rate:  0.9622, Loss :  6.7311, Time:  10.3917s, Time per sample:  0.0438s
# +---------------------------------------------+
# ==============================
#
#
# Making Directory: Results/Noisy/dog_bark
# Making Directory: Results/Noisy/dog_bark/30
# =============================
# Starting Noisy Testing for: Whisper for dog_bark noise at an SNR of 30
# > Initialising model: Whisper
# **************************************************************
# Testing Best Model found at: Model Checkpoints/Whisper Checkpoints/best_Whisper_checkpoint.pth.tar
# **************************************************************
# > Initialising model: Whisper
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 40
# Evaluation accuracy:  0.6296, Phoneme Error Rate:  0.3704, Loss :  0.7787, Time:  14.7850s, Time per sample:  0.3696s
# +---------------------------------------------+
# ==============================
#
#
# =============================
# Starting Noisy Testing for: Whisper_80 for dog_bark noise at an SNR of 30
# > Initialising model: Whisper_80
# **************************************************************
# Testing Best Model found at: Model Checkpoints/Whisper_80 Checkpoints/best_Whisper_80_checkpoint.pth.tar
# **************************************************************
# > Initialising model: Whisper_80
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 40
# Evaluation accuracy:  0.6150, Phoneme Error Rate:  0.3850, Loss :  0.7803, Time:  14.8190s, Time per sample:  0.3705s
# +---------------------------------------------+
# ==============================
#
#
# =============================
# Starting Noisy Testing for: SIG_Extract_3.0 for dog_bark noise at an SNR of 30
# > Initialising model: SIG_Extract_3.0
# **************************************************************
# Testing Best Model found at: Model Checkpoints/SIG_Extract_3.0 Checkpoints/best_SIG_Extract_3.0_checkpoint.pth.tar
# **************************************************************
# > Initialising model: SIG_Extract_3.0
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 237
# Evaluation accuracy:  0.5588, Phoneme Error Rate:  0.4412, Loss :  1.1575, Time:  9.6855s, Time per sample:  0.0409s
# +---------------------------------------------+
# ==============================
#
#
# Making Directory: Results/Noisy/dog_bark/25
# =============================
# Starting Noisy Testing for: Whisper for dog_bark noise at an SNR of 25
# > Initialising model: Whisper
# **************************************************************
# Testing Best Model found at: Model Checkpoints/Whisper Checkpoints/best_Whisper_checkpoint.pth.tar
# **************************************************************
# > Initialising model: Whisper
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 40
# Evaluation accuracy:  0.5986, Phoneme Error Rate:  0.4014, Loss :  0.8814, Time:  14.7847s, Time per sample:  0.3696s
# +---------------------------------------------+
# ==============================
#
#
# =============================
# Starting Noisy Testing for: Whisper_80 for dog_bark noise at an SNR of 25
# > Initialising model: Whisper_80
# **************************************************************
# Testing Best Model found at: Model Checkpoints/Whisper_80 Checkpoints/best_Whisper_80_checkpoint.pth.tar
# **************************************************************
# > Initialising model: Whisper_80
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 40
# Evaluation accuracy:  0.5879, Phoneme Error Rate:  0.4121, Loss :  0.8568, Time:  14.7780s, Time per sample:  0.3695s
# +---------------------------------------------+
# ==============================
#
#
# =============================
# Starting Noisy Testing for: SIG_Extract_3.0 for dog_bark noise at an SNR of 25
# > Initialising model: SIG_Extract_3.0
# **************************************************************
# Testing Best Model found at: Model Checkpoints/SIG_Extract_3.0 Checkpoints/best_SIG_Extract_3.0_checkpoint.pth.tar
# **************************************************************
# > Initialising model: SIG_Extract_3.0
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 237
# Evaluation accuracy:  0.5462, Phoneme Error Rate:  0.4538, Loss :  1.2031, Time:  9.6807s, Time per sample:  0.0408s
# +---------------------------------------------+
# ==============================
#
#
# Making Directory: Results/Noisy/dog_bark/20
# =============================
# Starting Noisy Testing for: Whisper for dog_bark noise at an SNR of 20
# > Initialising model: Whisper
# **************************************************************
# Testing Best Model found at: Model Checkpoints/Whisper Checkpoints/best_Whisper_checkpoint.pth.tar
# **************************************************************
# > Initialising model: Whisper
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 40
# ...
# +---------------------------------------------+
# ==============================
#
#
# =============================
# Starting Noisy Testing for: Whisper_80 for children_playing noise at an SNR of 20
# > Initialising model: Whisper_80
# **************************************************************
# Testing Best Model found at: Model Checkpoints/Whisper_80 Checkpoints/best_Whisper_80_checkpoint.pth.tar
# **************************************************************
# > Initialising model: Whisper_80
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 40
# Evaluation accuracy:  0.4963, Phoneme Error Rate:  0.5037, Loss :  1.1578, Time:  14.8471s, Time per sample:  0.3712s
# +---------------------------------------------+
# ==============================
#
#
# =============================
# Starting Noisy Testing for: SIG_Extract_3.0 for children_playing noise at an SNR of 20
# > Initialising model: SIG_Extract_3.0
# **************************************************************
# Testing Best Model found at: Model Checkpoints/SIG_Extract_3.0 Checkpoints/best_SIG_Extract_3.0_checkpoint.pth.tar
# **************************************************************
# > Initialising model: SIG_Extract_3.0
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 237
# Evaluation accuracy:  0.4816, Phoneme Error Rate:  0.5184, Loss :  1.4048, Time:  9.8757s, Time per sample:  0.0417s
# +---------------------------------------------+
# ==============================
#
#
# Making Directory: Results/Noisy/children_playing/15
# =============================
# Starting Noisy Testing for: Whisper for children_playing noise at an SNR of 15
# > Initialising model: Whisper
# **************************************************************
# Testing Best Model found at: Model Checkpoints/Whisper Checkpoints/best_Whisper_checkpoint.pth.tar
# **************************************************************
# > Initialising model: Whisper
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 40
# Evaluation accuracy:  0.4041, Phoneme Error Rate:  0.5959, Loss :  2.2645, Time:  14.9489s, Time per sample:  0.3737s
# +---------------------------------------------+
# ==============================
#
#
# =============================
# Starting Noisy Testing for: Whisper_80 for children_playing noise at an SNR of 15
# > Initialising model: Whisper_80
# **************************************************************
# Testing Best Model found at: Model Checkpoints/Whisper_80 Checkpoints/best_Whisper_80_checkpoint.pth.tar
# **************************************************************
# > Initialising model: Whisper_80
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 40
# Evaluation accuracy:  0.3812, Phoneme Error Rate:  0.6188, Loss :  1.9031, Time:  15.0033s, Time per sample:  0.3751s
# +---------------------------------------------+
# ==============================
#
#
# =============================
# Starting Noisy Testing for: SIG_Extract_3.0 for children_playing noise at an SNR of 15
# > Initialising model: SIG_Extract_3.0
# **************************************************************
# Testing Best Model found at: Model Checkpoints/SIG_Extract_3.0 Checkpoints/best_SIG_Extract_3.0_checkpoint.pth.tar
# **************************************************************
# > Initialising model: SIG_Extract_3.0
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 237
# Evaluation accuracy:  0.3645, Phoneme Error Rate:  0.6355, Loss :  1.7857, Time:  9.9313s, Time per sample:  0.0419s
# +---------------------------------------------+
# ==============================
#
#
# Making Directory: Results/Noisy/children_playing/10
# =============================
# Starting Noisy Testing for: Whisper for children_playing noise at an SNR of 10
# > Initialising model: Whisper
# **************************************************************
# Testing Best Model found at: Model Checkpoints/Whisper Checkpoints/best_Whisper_checkpoint.pth.tar
# **************************************************************
# > Initialising model: Whisper
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 40
# Evaluation accuracy:  0.2866, Phoneme Error Rate:  0.7134, Loss :  5.8577, Time:  15.2659s, Time per sample:  0.3816s
# +---------------------------------------------+
# ==============================
#
#
# =============================
# Starting Noisy Testing for: Whisper_80 for children_playing noise at an SNR of 10
# > Initialising model: Whisper_80
# **************************************************************
# Testing Best Model found at: Model Checkpoints/Whisper_80 Checkpoints/best_Whisper_80_checkpoint.pth.tar
# **************************************************************
# > Initialising model: Whisper_80
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 40
# Evaluation accuracy:  0.2683, Phoneme Error Rate:  0.7317, Loss :  4.2086, Time:  15.0189s, Time per sample:  0.3755s
# +---------------------------------------------+
# ==============================
#
#
# =============================
# Starting Noisy Testing for: SIG_Extract_3.0 for children_playing noise at an SNR of 10
# > Initialising model: SIG_Extract_3.0
# **************************************************************
# Testing Best Model found at: Model Checkpoints/SIG_Extract_3.0 Checkpoints/best_SIG_Extract_3.0_checkpoint.pth.tar
# **************************************************************
# > Initialising model: SIG_Extract_3.0
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 237
# Evaluation accuracy:  0.2583, Phoneme Error Rate:  0.7417, Loss :  2.4043, Time:  10.2041s, Time per sample:  0.0431s
# +---------------------------------------------+
# ==============================
#
#
# Making Directory: Results/Noisy/children_playing/5
# =============================
# Starting Noisy Testing for: Whisper for children_playing noise at an SNR of 5
# > Initialising model: Whisper
# **************************************************************
# Testing Best Model found at: Model Checkpoints/Whisper Checkpoints/best_Whisper_checkpoint.pth.tar
# **************************************************************
# > Initialising model: Whisper
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 40
# Evaluation accuracy:  0.1863, Phoneme Error Rate:  0.8137, Loss :  19.7995, Time:  15.1955s, Time per sample:  0.3799s
# +---------------------------------------------+
# ==============================
#
#
# =============================
# Starting Noisy Testing for: Whisper_80 for children_playing noise at an SNR of 5
# > Initialising model: Whisper_80
# **************************************************************
# Testing Best Model found at: Model Checkpoints/Whisper_80 Checkpoints/best_Whisper_80_checkpoint.pth.tar
# **************************************************************
# > Initialising model: Whisper_80
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 40
# Evaluation accuracy:  0.1733, Phoneme Error Rate:  0.8267, Loss :  12.1898, Time:  15.0779s, Time per sample:  0.3769s
# +---------------------------------------------+
# ==============================
#
#
# =============================
# Starting Noisy Testing for: SIG_Extract_3.0 for children_playing noise at an SNR of 5
# > Initialising model: SIG_Extract_3.0
# **************************************************************
# Testing Best Model found at: Model Checkpoints/SIG_Extract_3.0 Checkpoints/best_SIG_Extract_3.0_checkpoint.pth.tar
# **************************************************************
# > Initialising model: SIG_Extract_3.0
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 237
# Evaluation accuracy:  0.1781, Phoneme Error Rate:  0.8219, Loss :  3.2474, Time:  10.1557s, Time per sample:  0.0429s
# +---------------------------------------------+
# ==============================
#
#
# Making Directory: Results/Noisy/children_playing/0
# =============================
# Starting Noisy Testing for: Whisper for children_playing noise at an SNR of 0
# > Initialising model: Whisper
# **************************************************************
# Testing Best Model found at: Model Checkpoints/Whisper Checkpoints/best_Whisper_checkpoint.pth.tar
# **************************************************************
# > Initialising model: Whisper
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 40
# Evaluation accuracy:  0.1135, Phoneme Error Rate:  0.8865, Loss :  72.5559, Time:  15.1143s, Time per sample:  0.3779s
# +---------------------------------------------+
# ==============================
#
#
# =============================
# Starting Noisy Testing for: Whisper_80 for children_playing noise at an SNR of 0
# > Initialising model: Whisper_80
# **************************************************************
# Testing Best Model found at: Model Checkpoints/Whisper_80 Checkpoints/best_Whisper_80_checkpoint.pth.tar
# **************************************************************
# > Initialising model: Whisper_80
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 40
# Evaluation accuracy:  0.1065, Phoneme Error Rate:  0.8935, Loss :  39.5159, Time:  15.1047s, Time per sample:  0.3776s
# +---------------------------------------------+
# ==============================
#
#
# =============================
# Starting Noisy Testing for: SIG_Extract_3.0 for children_playing noise at an SNR of 0
# > Initialising model: SIG_Extract_3.0
# **************************************************************
# Testing Best Model found at: Model Checkpoints/SIG_Extract_3.0 Checkpoints/best_SIG_Extract_3.0_checkpoint.pth.tar
# **************************************************************
# > Initialising model: SIG_Extract_3.0
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 237
# Evaluation accuracy:  0.1192, Phoneme Error Rate:  0.8808, Loss :  4.0956, Time:  10.3577s, Time per sample:  0.0437s
# +---------------------------------------------+
# ==============================
#
#
# Making Directory: Results/Noisy/children_playing/-5
# =============================
# Starting Noisy Testing for: Whisper for children_playing noise at an SNR of -5
# > Initialising model: Whisper
# **************************************************************
# Testing Best Model found at: Model Checkpoints/Whisper Checkpoints/best_Whisper_checkpoint.pth.tar
# **************************************************************
# > Initialising model: Whisper
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 40
# Evaluation accuracy:  0.0696, Phoneme Error Rate:  0.9304, Loss :  258.9582, Time:  15.1358s, Time per sample:  0.3784s
# +---------------------------------------------+
# ==============================
#
#
# =============================
# Starting Noisy Testing for: Whisper_80 for children_playing noise at an SNR of -5
# > Initialising model: Whisper_80
# **************************************************************
# Testing Best Model found at: Model Checkpoints/Whisper_80 Checkpoints/best_Whisper_80_checkpoint.pth.tar
# **************************************************************
# > Initialising model: Whisper_80
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 40
# Evaluation accuracy:  0.0679, Phoneme Error Rate:  0.9321, Loss :  129.0821, Time:  15.3102s, Time per sample:  0.3828s
# +---------------------------------------------+
# ==============================
#
#
# =============================
# Starting Noisy Testing for: SIG_Extract_3.0 for children_playing noise at an SNR of -5
# > Initialising model: SIG_Extract_3.0
# **************************************************************
# Testing Best Model found at: Model Checkpoints/SIG_Extract_3.0 Checkpoints/best_SIG_Extract_3.0_checkpoint.pth.tar
# **************************************************************
# > Initialising model: SIG_Extract_3.0
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 237
# Evaluation accuracy:  0.0820, Phoneme Error Rate:  0.9180, Loss :  4.7339, Time:  10.4386s, Time per sample:  0.0440s
# +---------------------------------------------+
# ==============================
#
#
# Making Directory: Results/Noisy/children_playing/-10
# =============================
# Starting Noisy Testing for: Whisper for children_playing noise at an SNR of -10
# > Initialising model: Whisper
# **************************************************************
# Testing Best Model found at: Model Checkpoints/Whisper Checkpoints/best_Whisper_checkpoint.pth.tar
# **************************************************************
# > Initialising model: Whisper
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 40
# Evaluation accuracy:  0.0465, Phoneme Error Rate:  0.9535, Loss :  881.0435, Time:  15.8654s, Time per sample:  0.3966s
# +---------------------------------------------+
# ==============================
#
#
# =============================
# Starting Noisy Testing for: Whisper_80 for children_playing noise at an SNR of -10
# > Initialising model: Whisper_80
# **************************************************************
# Testing Best Model found at: Model Checkpoints/Whisper_80 Checkpoints/best_Whisper_80_checkpoint.pth.tar
# **************************************************************
# > Initialising model: Whisper_80
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 40
# Evaluation accuracy:  0.0482, Phoneme Error Rate:  0.9518, Loss :  416.6020, Time:  15.3169s, Time per sample:  0.3829s
# +---------------------------------------------+
# ==============================
#
#
# =============================
# Starting Noisy Testing for: SIG_Extract_3.0 for children_playing noise at an SNR of -10
# > Initialising model: SIG_Extract_3.0
# **************************************************************
# Testing Best Model found at: Model Checkpoints/SIG_Extract_3.0 Checkpoints/best_SIG_Extract_3.0_checkpoint.pth.tar
# **************************************************************
# > Initialising model: SIG_Extract_3.0
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 237
# Evaluation accuracy:  0.0604, Phoneme Error Rate:  0.9396, Loss :  5.1015, Time:  10.7363s, Time per sample:  0.0453s
# +---------------------------------------------+
# ==============================

# %% [markdown]
# ### IHC Models testing
#
# Only the models that performed well on k-Fold stability testing are tested here, as we want to give our models a fair chance.

# %%
#IHC_models=["IHC_Cpc", "IHC_Wav2vec2", "IHC_Extract_512", "IHC_Extract", "IHC_Cpc_80", "IHC_Wav2vec2_80",   "IHC_Extract_2.0", "IHC_Extract_3.0"]

IHC_models=["IHC_Extract_3.0"]
            
noise_types=['White','air_conditioner', 'dog_bark', 'street_music', 'children_playing']
    
for noise in noise_types:

    dir_snr = Path("./Results/Noisy/{}".format(noise))
    dir_snr.mkdir(parents=True, exist_ok=True)
    print("Making Directory: %s" % dir_snr)
    
    for snr in SNRs:
        dir_snr = Path("./Results/Noisy/{}/{}".format(noise, snr))
        dir_snr.mkdir(parents=True, exist_ok=True)
        print("Making Directory: %s" % dir_snr)
        
        test_accuracies={}

        #Reload any old results so that we can continue training if required
        test_location='Results/Noisy/{}/{}/IHC_models.pkl'.format(noise, snr)
        if(Path(test_location).is_file()):
            with open(test_location, 'rb') as f:
                test_accuracies = pickle.load(f)
            
        for model in IHC_models:
            print("=============================")
            print("Starting Noisy Testing for: %s for %s noise at an SNR of %d" %(model, noise, snr))
            
            #Test the model on the noisy dataset
            test_accu, test_loss, unique_phonemes, time=TrainEvalFunctions.test_best(model, distributed=False,  noise=True , noise_type= noise, SNR= snr)

            test_accuracies["{}-Clean".format(model)]=test_accu

            print("==============================")
            print("")
            print("")

        with open(test_location, 'wb') as f:
            pickle.dump(test_accuracies, f)
# Out:
# Making Directory: Results/Noisy/White
# Making Directory: Results/Noisy/White/30
# =============================
# Starting Noisy Testing for: IHC_Extract_3.0 for White noise at an SNR of 30
# > Initialising model: IHC_Extract_3.0
# **************************************************************
# Testing Best Model found at: Model Checkpoints/IHC_Extract_3.0 Checkpoints/best_IHC_Extract_3.0_checkpoint.pth.tar
# **************************************************************
# > Initialising model: IHC_Extract_3.0
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 237
# Evaluation accuracy:  0.5018, Phoneme Error Rate:  0.4982, Loss :  1.3331, Time:  61.0056s, Time per sample:  0.2574s
# +---------------------------------------------+
# ==============================
#
#
# Making Directory: Results/Noisy/White/25
# =============================
# Starting Noisy Testing for: IHC_Extract_3.0 for White noise at an SNR of 25
# > Initialising model: IHC_Extract_3.0
# **************************************************************
# Testing Best Model found at: Model Checkpoints/IHC_Extract_3.0 Checkpoints/best_IHC_Extract_3.0_checkpoint.pth.tar
# **************************************************************
# > Initialising model: IHC_Extract_3.0
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 237
# Evaluation accuracy:  0.4388, Phoneme Error Rate:  0.5612, Loss :  1.4849, Time:  60.9114s, Time per sample:  0.2570s
# +---------------------------------------------+
# ==============================
#
#
# Making Directory: Results/Noisy/White/20
# =============================
# Starting Noisy Testing for: IHC_Extract_3.0 for White noise at an SNR of 20
# > Initialising model: IHC_Extract_3.0
# **************************************************************
# Testing Best Model found at: Model Checkpoints/IHC_Extract_3.0 Checkpoints/best_IHC_Extract_3.0_checkpoint.pth.tar
# **************************************************************
# > Initialising model: IHC_Extract_3.0
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 237
# Evaluation accuracy:  0.3573, Phoneme Error Rate:  0.6427, Loss :  1.6965, Time:  60.9591s, Time per sample:  0.2572s
# +---------------------------------------------+
# ==============================
#
#
# Making Directory: Results/Noisy/White/15
# =============================
# Starting Noisy Testing for: IHC_Extract_3.0 for White noise at an SNR of 15
# > Initialising model: IHC_Extract_3.0
# **************************************************************
# Testing Best Model found at: Model Checkpoints/IHC_Extract_3.0 Checkpoints/best_IHC_Extract_3.0_checkpoint.pth.tar
# **************************************************************
# > Initialising model: IHC_Extract_3.0
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 237
# Evaluation accuracy:  0.2577, Phoneme Error Rate:  0.7423, Loss :  1.9893, Time:  61.2206s, Time per sample:  0.2583s
# +---------------------------------------------+
# ==============================
#
#
# Making Directory: Results/Noisy/White/10
# =============================
# Starting Noisy Testing for: IHC_Extract_3.0 for White noise at an SNR of 10
# > Initialising model: IHC_Extract_3.0
# **************************************************************
# Testing Best Model found at: Model Checkpoints/IHC_Extract_3.0 Checkpoints/best_IHC_Extract_3.0_checkpoint.pth.tar
# **************************************************************
# > Initialising model: IHC_Extract_3.0
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 237
# Evaluation accuracy:  0.1761, Phoneme Error Rate:  0.8239, Loss :  2.3768, Time:  61.2277s, Time per sample:  0.2583s
# +---------------------------------------------+
# ==============================
#
#
# Making Directory: Results/Noisy/White/5
# =============================
# Starting Noisy Testing for: IHC_Extract_3.0 for White noise at an SNR of 5
# > Initialising model: IHC_Extract_3.0
# **************************************************************
# Testing Best Model found at: Model Checkpoints/IHC_Extract_3.0 Checkpoints/best_IHC_Extract_3.0_checkpoint.pth.tar
# **************************************************************
# > Initialising model: IHC_Extract_3.0
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 237
# Evaluation accuracy:  0.1184, Phoneme Error Rate:  0.8816, Loss :  2.9442, Time:  61.2601s, Time per sample:  0.2585s
# +---------------------------------------------+
# ==============================
#
#
# Making Directory: Results/Noisy/White/0
# =============================
# Starting Noisy Testing for: IHC_Extract_3.0 for White noise at an SNR of 0
# > Initialising model: IHC_Extract_3.0
# **************************************************************
# Testing Best Model found at: Model Checkpoints/IHC_Extract_3.0 Checkpoints/best_IHC_Extract_3.0_checkpoint.pth.tar
# **************************************************************
# > Initialising model: IHC_Extract_3.0
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 237
# Evaluation accuracy:  0.0755, Phoneme Error Rate:  0.9245, Loss :  3.9817, Time:  61.3646s, Time per sample:  0.2589s
# +---------------------------------------------+
# ==============================
#
#
# Making Directory: Results/Noisy/White/-5
# =============================
# Starting Noisy Testing for: IHC_Extract_3.0 for White noise at an SNR of -5
# > Initialising model: IHC_Extract_3.0
# **************************************************************
# Testing Best Model found at: Model Checkpoints/IHC_Extract_3.0 Checkpoints/best_IHC_Extract_3.0_checkpoint.pth.tar
# **************************************************************
# > Initialising model: IHC_Extract_3.0
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 237
# Evaluation accuracy:  0.0588, Phoneme Error Rate:  0.9412, Loss :  5.0106, Time:  61.2709s, Time per sample:  0.2585s
# +---------------------------------------------+
# ==============================
#
#
# Making Directory: Results/Noisy/White/-10
# =============================
# Starting Noisy Testing for: IHC_Extract_3.0 for White noise at an SNR of -10
# > Initialising model: IHC_Extract_3.0
# **************************************************************
# Testing Best Model found at: Model Checkpoints/IHC_Extract_3.0 Checkpoints/best_IHC_Extract_3.0_checkpoint.pth.tar
# **************************************************************
# > Initialising model: IHC_Extract_3.0
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 237
# Evaluation accuracy:  0.0517, Phoneme Error Rate:  0.9483, Loss :  5.6795, Time:  61.3223s, Time per sample:  0.2587s
# +---------------------------------------------+
# ==============================
#
#
# Making Directory: Results/Noisy/air_conditioner
# Making Directory: Results/Noisy/air_conditioner/30
# =============================
# Starting Noisy Testing for: IHC_Extract_3.0 for air_conditioner noise at an SNR of 30
# > Initialising model: IHC_Extract_3.0
# **************************************************************
# Testing Best Model found at: Model Checkpoints/IHC_Extract_3.0 Checkpoints/best_IHC_Extract_3.0_checkpoint.pth.tar
# **************************************************************
# > Initialising model: IHC_Extract_3.0
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 237
# Evaluation accuracy:  0.5415, Phoneme Error Rate:  0.4585, Loss :  1.1971, Time:  60.6840s, Time per sample:  0.2561s
# +---------------------------------------------+
# ==============================
#
#
# Making Directory: Results/Noisy/air_conditioner/25
# =============================
# Starting Noisy Testing for: IHC_Extract_3.0 for air_conditioner noise at an SNR of 25
# > Initialising model: IHC_Extract_3.0
# **************************************************************
# Testing Best Model found at: Model Checkpoints/IHC_Extract_3.0 Checkpoints/best_IHC_Extract_3.0_checkpoint.pth.tar
# **************************************************************
# > Initialising model: IHC_Extract_3.0
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 237
# Evaluation accuracy:  0.5247, Phoneme Error Rate:  0.4753, Loss :  1.2516, Time:  60.7160s, Time per sample:  0.2562s
# +---------------------------------------------+
# ==============================
#
#
# Making Directory: Results/Noisy/air_conditioner/20
# =============================
# Starting Noisy Testing for: IHC_Extract_3.0 for air_conditioner noise at an SNR of 20
# > Initialising model: IHC_Extract_3.0
# **************************************************************
# Testing Best Model found at: Model Checkpoints/IHC_Extract_3.0 Checkpoints/best_IHC_Extract_3.0_checkpoint.pth.tar
# **************************************************************
# > Initialising model: IHC_Extract_3.0
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 237
# Evaluation accuracy:  0.4740, Phoneme Error Rate:  0.5260, Loss :  1.3701, Time:  60.8490s, Time per sample:  0.2567s
# +---------------------------------------------+
# ==============================
#
#
# Making Directory: Results/Noisy/air_conditioner/15
# =============================
# Starting Noisy Testing for: IHC_Extract_3.0 for air_conditioner noise at an SNR of 15
# > Initialising model: IHC_Extract_3.0
# **************************************************************
# Testing Best Model found at: Model Checkpoints/IHC_Extract_3.0 Checkpoints/best_IHC_Extract_3.0_checkpoint.pth.tar
# **************************************************************
# > Initialising model: IHC_Extract_3.0
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 237
# Evaluation accuracy:  0.3883, Phoneme Error Rate:  0.6117, Loss :  1.5597, Time:  60.9500s, Time per sample:  0.2572s
# +---------------------------------------------+
# ==============================
#
#
# Making Directory: Results/Noisy/air_conditioner/10
# =============================
# Starting Noisy Testing for: IHC_Extract_3.0 for air_conditioner noise at an SNR of 10
# > Initialising model: IHC_Extract_3.0
# **************************************************************
# Testing Best Model found at: Model Checkpoints/IHC_Extract_3.0 Checkpoints/best_IHC_Extract_3.0_checkpoint.pth.tar
# **************************************************************
# > Initialising model: IHC_Extract_3.0
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 237
# Evaluation accuracy:  0.3134, Phoneme Error Rate:  0.6866, Loss :  1.7974, Time:  61.0202s, Time per sample:  0.2575s
# +---------------------------------------------+
# ==============================
#
#
# Making Directory: Results/Noisy/air_conditioner/5
# =============================
# Starting Noisy Testing for: IHC_Extract_3.0 for air_conditioner noise at an SNR of 5
# > Initialising model: IHC_Extract_3.0
# **************************************************************
# Testing Best Model found at: Model Checkpoints/IHC_Extract_3.0 Checkpoints/best_IHC_Extract_3.0_checkpoint.pth.tar
# **************************************************************
# > Initialising model: IHC_Extract_3.0
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 237
# Evaluation accuracy:  0.2403, Phoneme Error Rate:  0.7597, Loss :  2.1280, Time:  61.5671s, Time per sample:  0.2598s
# +---------------------------------------------+
# ==============================
#
#
# Making Directory: Results/Noisy/air_conditioner/0
# =============================
# Starting Noisy Testing for: IHC_Extract_3.0 for air_conditioner noise at an SNR of 0
# > Initialising model: IHC_Extract_3.0
# **************************************************************
# Testing Best Model found at: Model Checkpoints/IHC_Extract_3.0 Checkpoints/best_IHC_Extract_3.0_checkpoint.pth.tar
# **************************************************************
# > Initialising model: IHC_Extract_3.0
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 237
# Evaluation accuracy:  0.1812, Phoneme Error Rate:  0.8188, Loss :  2.5928, Time:  61.1488s, Time per sample:  0.2580s
# +---------------------------------------------+
# ==============================
#
#
# Making Directory: Results/Noisy/air_conditioner/-5
# =============================
# Starting Noisy Testing for: IHC_Extract_3.0 for air_conditioner noise at an SNR of -5
# > Initialising model: IHC_Extract_3.0
# **************************************************************
# Testing Best Model found at: Model Checkpoints/IHC_Extract_3.0 Checkpoints/best_IHC_Extract_3.0_checkpoint.pth.tar
# **************************************************************
# > Initialising model: IHC_Extract_3.0
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 237
# Evaluation accuracy:  0.1347, Phoneme Error Rate:  0.8653, Loss :  3.0675, Time:  61.2943s, Time per sample:  0.2586s
# +---------------------------------------------+
# ==============================
#
#
# Making Directory: Results/Noisy/air_conditioner/-10
# =============================
# Starting Noisy Testing for: IHC_Extract_3.0 for air_conditioner noise at an SNR of -10
# > Initialising model: IHC_Extract_3.0
# **************************************************************
# Testing Best Model found at: Model Checkpoints/IHC_Extract_3.0 Checkpoints/best_IHC_Extract_3.0_checkpoint.pth.tar
# **************************************************************
# > Initialising model: IHC_Extract_3.0
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 237
# Evaluation accuracy:  0.1020, Phoneme Error Rate:  0.8980, Loss :  3.4139, Time:  61.2872s, Time per sample:  0.2586s
# +---------------------------------------------+
# ==============================
#
#
# Making Directory: Results/Noisy/dog_bark
# Making Directory: Results/Noisy/dog_bark/30
# =============================
# Starting Noisy Testing for: IHC_Extract_3.0 for dog_bark noise at an SNR of 30
# > Initialising model: IHC_Extract_3.0
# **************************************************************
# Testing Best Model found at: Model Checkpoints/IHC_Extract_3.0 Checkpoints/best_IHC_Extract_3.0_checkpoint.pth.tar
# **************************************************************
# > Initialising model: IHC_Extract_3.0
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 237
# Evaluation accuracy:  0.5436, Phoneme Error Rate:  0.4564, Loss :  1.1896, Time:  60.7129s, Time per sample:  0.2562s
# +---------------------------------------------+
# ==============================
#
#
# Making Directory: Results/Noisy/dog_bark/25
# =============================
# Starting Noisy Testing for: IHC_Extract_3.0 for dog_bark noise at an SNR of 25
# > Initialising model: IHC_Extract_3.0
# **************************************************************
# Testing Best Model found at: Model Checkpoints/IHC_Extract_3.0 Checkpoints/best_IHC_Extract_3.0_checkpoint.pth.tar
# **************************************************************
# > Initialising model: IHC_Extract_3.0
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 237
# Evaluation accuracy:  0.5324, Phoneme Error Rate:  0.4676, Loss :  1.2247, Time:  60.7818s, Time per sample:  0.2565s
# +---------------------------------------------+
# ==============================
#
#
# Making Directory: Results/Noisy/dog_bark/20
# =============================
# Starting Noisy Testing for: IHC_Extract_3.0 for dog_bark noise at an SNR of 20
# > Initialising model: IHC_Extract_3.0
# **************************************************************
# Testing Best Model found at: Model Checkpoints/IHC_Extract_3.0 Checkpoints/best_IHC_Extract_3.0_checkpoint.pth.tar
# **************************************************************
# > Initialising model: IHC_Extract_3.0
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 237
# Evaluation accuracy:  0.5085, Phoneme Error Rate:  0.4915, Loss :  1.2942, Time:  60.7830s, Time per sample:  0.2565s
# +---------------------------------------------+
# ==============================
#
#
# Making Directory: Results/Noisy/dog_bark/15
# =============================
# Starting Noisy Testing for: IHC_Extract_3.0 for dog_bark noise at an SNR of 15
# > Initialising model: IHC_Extract_3.0
# **************************************************************
# Testing Best Model found at: Model Checkpoints/IHC_Extract_3.0 Checkpoints/best_IHC_Extract_3.0_checkpoint.pth.tar
# **************************************************************
# > Initialising model: IHC_Extract_3.0
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 237
# Evaluation accuracy:  0.4654, Phoneme Error Rate:  0.5346, Loss :  1.4150, Time:  60.8427s, Time per sample:  0.2567s
# +---------------------------------------------+
# ==============================
#
#
# Making Directory: Results/Noisy/dog_bark/10
# =============================
# Starting Noisy Testing for: IHC_Extract_3.0 for dog_bark noise at an SNR of 10
# > Initialising model: IHC_Extract_3.0
# **************************************************************
# Testing Best Model found at: Model Checkpoints/IHC_Extract_3.0 Checkpoints/best_IHC_Extract_3.0_checkpoint.pth.tar
# **************************************************************
# > Initialising model: IHC_Extract_3.0
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 237
# Evaluation accuracy:  0.4034, Phoneme Error Rate:  0.5966, Loss :  1.6031, Time:  60.9070s, Time per sample:  0.2570s
# +---------------------------------------------+
# ==============================
#
#
# Making Directory: Results/Noisy/dog_bark/5
# =============================
# Starting Noisy Testing for: IHC_Extract_3.0 for dog_bark noise at an SNR of 5
# > Initialising model: IHC_Extract_3.0
# **************************************************************
# Testing Best Model found at: Model Checkpoints/IHC_Extract_3.0 Checkpoints/best_IHC_Extract_3.0_checkpoint.pth.tar
# **************************************************************
# > Initialising model: IHC_Extract_3.0
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 237
# Evaluation accuracy:  0.3391, Phoneme Error Rate:  0.6609, Loss :  1.8768, Time:  60.9093s, Time per sample:  0.2570s
# +---------------------------------------------+
# ==============================
#
#
# Making Directory: Results/Noisy/dog_bark/0
# =============================
# Starting Noisy Testing for: IHC_Extract_3.0 for dog_bark noise at an SNR of 0
# > Initialising model: IHC_Extract_3.0
# **************************************************************
# Testing Best Model found at: Model Checkpoints/IHC_Extract_3.0 Checkpoints/best_IHC_Extract_3.0_checkpoint.pth.tar
# **************************************************************
# > Initialising model: IHC_Extract_3.0
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 237
# Evaluation accuracy:  0.2784, Phoneme Error Rate:  0.7216, Loss :  2.2434, Time:  61.0217s, Time per sample:  0.2575s
# +---------------------------------------------+
# ==============================
#
#
# Making Directory: Results/Noisy/dog_bark/-5
# =============================
# Starting Noisy Testing for: IHC_Extract_3.0 for dog_bark noise at an SNR of -5
# > Initialising model: IHC_Extract_3.0
# **************************************************************
# Testing Best Model found at: Model Checkpoints/IHC_Extract_3.0 Checkpoints/best_IHC_Extract_3.0_checkpoint.pth.tar
# **************************************************************
# > Initialising model: IHC_Extract_3.0
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 237
# Evaluation accuracy:  0.2274, Phoneme Error Rate:  0.7726, Loss :  2.6387, Time:  61.1891s, Time per sample:  0.2582s
# +---------------------------------------------+
# ==============================
#
#
# Making Directory: Results/Noisy/dog_bark/-10
# =============================
# Starting Noisy Testing for: IHC_Extract_3.0 for dog_bark noise at an SNR of -10
# > Initialising model: IHC_Extract_3.0
# **************************************************************
# Testing Best Model found at: Model Checkpoints/IHC_Extract_3.0 Checkpoints/best_IHC_Extract_3.0_checkpoint.pth.tar
# **************************************************************
# > Initialising model: IHC_Extract_3.0
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 237
# Evaluation accuracy:  0.1808, Phoneme Error Rate:  0.8192, Loss :  3.0012, Time:  61.2538s, Time per sample:  0.2585s
# +---------------------------------------------+
# ==============================
#
#
# Making Directory: Results/Noisy/street_music
# Making Directory: Results/Noisy/street_music/30
# =============================
# Starting Noisy Testing for: IHC_Extract_3.0 for street_music noise at an SNR of 30
# > Initialising model: IHC_Extract_3.0
# **************************************************************
# Testing Best Model found at: Model Checkpoints/IHC_Extract_3.0 Checkpoints/best_IHC_Extract_3.0_checkpoint.pth.tar
# **************************************************************
# > Initialising model: IHC_Extract_3.0
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 237
# Evaluation accuracy:  0.5404, Phoneme Error Rate:  0.4596, Loss :  1.2024, Time:  60.8126s, Time per sample:  0.2566s
# +---------------------------------------------+
# ==============================
#
#
# Making Directory: Results/Noisy/street_music/25
# =============================
# Starting Noisy Testing for: IHC_Extract_3.0 for street_music noise at an SNR of 25
# > Initialising model: IHC_Extract_3.0
# **************************************************************
# Testing Best Model found at: Model Checkpoints/IHC_Extract_3.0 Checkpoints/best_IHC_Extract_3.0_checkpoint.pth.tar
# **************************************************************
# > Initialising model: IHC_Extract_3.0
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 237
# Evaluation accuracy:  0.5192, Phoneme Error Rate:  0.4808, Loss :  1.2662, Time:  60.7414s, Time per sample:  0.2563s
# +---------------------------------------------+
# ==============================
#
#
# Making Directory: Results/Noisy/street_music/20
# =============================
# Starting Noisy Testing for: IHC_Extract_3.0 for street_music noise at an SNR of 20
# > Initialising model: IHC_Extract_3.0
# **************************************************************
# Testing Best Model found at: Model Checkpoints/IHC_Extract_3.0 Checkpoints/best_IHC_Extract_3.0_checkpoint.pth.tar
# **************************************************************
# > Initialising model: IHC_Extract_3.0
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 237
# Evaluation accuracy:  0.4662, Phoneme Error Rate:  0.5338, Loss :  1.3971, Time:  60.9151s, Time per sample:  0.2570s
# +---------------------------------------------+
# ==============================
#
#
# Making Directory: Results/Noisy/street_music/15
# =============================
# Starting Noisy Testing for: IHC_Extract_3.0 for street_music noise at an SNR of 15
# > Initialising model: IHC_Extract_3.0
# **************************************************************
# Testing Best Model found at: Model Checkpoints/IHC_Extract_3.0 Checkpoints/best_IHC_Extract_3.0_checkpoint.pth.tar
# **************************************************************
# > Initialising model: IHC_Extract_3.0
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 237
# Evaluation accuracy:  0.3862, Phoneme Error Rate:  0.6138, Loss :  1.6072, Time:  61.3555s, Time per sample:  0.2589s
# +---------------------------------------------+
# ==============================
#
#
# Making Directory: Results/Noisy/street_music/10
# =============================
# Starting Noisy Testing for: IHC_Extract_3.0 for street_music noise at an SNR of 10
# > Initialising model: IHC_Extract_3.0
# **************************************************************
# Testing Best Model found at: Model Checkpoints/IHC_Extract_3.0 Checkpoints/best_IHC_Extract_3.0_checkpoint.pth.tar
# **************************************************************
# > Initialising model: IHC_Extract_3.0
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 237
# Evaluation accuracy:  0.3041, Phoneme Error Rate:  0.6959, Loss :  1.9161, Time:  61.0287s, Time per sample:  0.2575s
# +---------------------------------------------+
# ==============================
#
#
# Making Directory: Results/Noisy/street_music/5
# =============================
# Starting Noisy Testing for: IHC_Extract_3.0 for street_music noise at an SNR of 5
# > Initialising model: IHC_Extract_3.0
# **************************************************************
# Testing Best Model found at: Model Checkpoints/IHC_Extract_3.0 Checkpoints/best_IHC_Extract_3.0_checkpoint.pth.tar
# **************************************************************
# > Initialising model: IHC_Extract_3.0
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 237
# Evaluation accuracy:  0.2225, Phoneme Error Rate:  0.7775, Loss :  2.4300, Time:  61.1220s, Time per sample:  0.2579s
# +---------------------------------------------+
# ==============================
#
#
# Making Directory: Results/Noisy/street_music/0
# =============================
# Starting Noisy Testing for: IHC_Extract_3.0 for street_music noise at an SNR of 0
# > Initialising model: IHC_Extract_3.0
# **************************************************************
# Testing Best Model found at: Model Checkpoints/IHC_Extract_3.0 Checkpoints/best_IHC_Extract_3.0_checkpoint.pth.tar
# **************************************************************
# > Initialising model: IHC_Extract_3.0
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 237
# Evaluation accuracy:  0.1520, Phoneme Error Rate:  0.8480, Loss :  3.1997, Time:  61.1757s, Time per sample:  0.2581s
# +---------------------------------------------+
# ==============================
#
#
# Making Directory: Results/Noisy/street_music/-5
# =============================
# Starting Noisy Testing for: IHC_Extract_3.0 for street_music noise at an SNR of -5
# > Initialising model: IHC_Extract_3.0
# **************************************************************
# Testing Best Model found at: Model Checkpoints/IHC_Extract_3.0 Checkpoints/best_IHC_Extract_3.0_checkpoint.pth.tar
# **************************************************************
# > Initialising model: IHC_Extract_3.0
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 237
# Evaluation accuracy:  0.1110, Phoneme Error Rate:  0.8890, Loss :  3.8630, Time:  61.2683s, Time per sample:  0.2585s
# +---------------------------------------------+
# ==============================
#
#
# Making Directory: Results/Noisy/street_music/-10
# =============================
# Starting Noisy Testing for: IHC_Extract_3.0 for street_music noise at an SNR of -10
# > Initialising model: IHC_Extract_3.0
# **************************************************************
# Testing Best Model found at: Model Checkpoints/IHC_Extract_3.0 Checkpoints/best_IHC_Extract_3.0_checkpoint.pth.tar
# **************************************************************
# > Initialising model: IHC_Extract_3.0
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 237
# Evaluation accuracy:  0.0878, Phoneme Error Rate:  0.9122, Loss :  4.2483, Time:  61.4489s, Time per sample:  0.2593s
# +---------------------------------------------+
# ==============================
#
#
# Making Directory: Results/Noisy/children_playing
# Making Directory: Results/Noisy/children_playing/30
# =============================
# Starting Noisy Testing for: IHC_Extract_3.0 for children_playing noise at an SNR of 30
# > Initialising model: IHC_Extract_3.0
# **************************************************************
# Testing Best Model found at: Model Checkpoints/IHC_Extract_3.0 Checkpoints/best_IHC_Extract_3.0_checkpoint.pth.tar
# **************************************************************
# > Initialising model: IHC_Extract_3.0
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 237
# Evaluation accuracy:  0.5399, Phoneme Error Rate:  0.4601, Loss :  1.2073, Time:  60.7355s, Time per sample:  0.2563s
# +---------------------------------------------+
# ==============================
#
#
# Making Directory: Results/Noisy/children_playing/25
# =============================
# Starting Noisy Testing for: IHC_Extract_3.0 for children_playing noise at an SNR of 25
# > Initialising model: IHC_Extract_3.0
# **************************************************************
# Testing Best Model found at: Model Checkpoints/IHC_Extract_3.0 Checkpoints/best_IHC_Extract_3.0_checkpoint.pth.tar
# **************************************************************
# > Initialising model: IHC_Extract_3.0
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 237
# Evaluation accuracy:  0.5184, Phoneme Error Rate:  0.4816, Loss :  1.2762, Time:  60.7980s, Time per sample:  0.2565s
# +---------------------------------------------+
# ==============================
#
#
# Making Directory: Results/Noisy/children_playing/20
# =============================
# Starting Noisy Testing for: IHC_Extract_3.0 for children_playing noise at an SNR of 20
# > Initialising model: IHC_Extract_3.0
# **************************************************************
# Testing Best Model found at: Model Checkpoints/IHC_Extract_3.0 Checkpoints/best_IHC_Extract_3.0_checkpoint.pth.tar
# **************************************************************
# > Initialising model: IHC_Extract_3.0
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 237
# Evaluation accuracy:  0.4623, Phoneme Error Rate:  0.5377, Loss :  1.4120, Time:  60.8407s, Time per sample:  0.2567s
# +---------------------------------------------+
# ==============================
#
#
# Making Directory: Results/Noisy/children_playing/15
# =============================
# Starting Noisy Testing for: IHC_Extract_3.0 for children_playing noise at an SNR of 15
# > Initialising model: IHC_Extract_3.0
# **************************************************************
# Testing Best Model found at: Model Checkpoints/IHC_Extract_3.0 Checkpoints/best_IHC_Extract_3.0_checkpoint.pth.tar
# **************************************************************
# > Initialising model: IHC_Extract_3.0
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 237
# Evaluation accuracy:  0.3788, Phoneme Error Rate:  0.6212, Loss :  1.6143, Time:  61.0367s, Time per sample:  0.2575s
# +---------------------------------------------+
# ==============================
#
#
# Making Directory: Results/Noisy/children_playing/10
# =============================
# Starting Noisy Testing for: IHC_Extract_3.0 for children_playing noise at an SNR of 10
# > Initialising model: IHC_Extract_3.0
# **************************************************************
# Testing Best Model found at: Model Checkpoints/IHC_Extract_3.0 Checkpoints/best_IHC_Extract_3.0_checkpoint.pth.tar
# **************************************************************
# > Initialising model: IHC_Extract_3.0
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 237
# Evaluation accuracy:  0.2972, Phoneme Error Rate:  0.7028, Loss :  1.8827, Time:  61.1255s, Time per sample:  0.2579s
# +---------------------------------------------+
# ==============================
#
#
# Making Directory: Results/Noisy/children_playing/5
# =============================
# Starting Noisy Testing for: IHC_Extract_3.0 for children_playing noise at an SNR of 5
# > Initialising model: IHC_Extract_3.0
# **************************************************************
# Testing Best Model found at: Model Checkpoints/IHC_Extract_3.0 Checkpoints/best_IHC_Extract_3.0_checkpoint.pth.tar
# **************************************************************
# > Initialising model: IHC_Extract_3.0
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 237
# Evaluation accuracy:  0.2163, Phoneme Error Rate:  0.7837, Loss :  2.3013, Time:  61.2287s, Time per sample:  0.2583s
# +---------------------------------------------+
# ==============================
#
#
# Making Directory: Results/Noisy/children_playing/0
# =============================
# Starting Noisy Testing for: IHC_Extract_3.0 for children_playing noise at an SNR of 0
# > Initialising model: IHC_Extract_3.0
# **************************************************************
# Testing Best Model found at: Model Checkpoints/IHC_Extract_3.0 Checkpoints/best_IHC_Extract_3.0_checkpoint.pth.tar
# **************************************************************
# > Initialising model: IHC_Extract_3.0
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 237
# Evaluation accuracy:  0.1457, Phoneme Error Rate:  0.8543, Loss :  2.9651, Time:  61.4529s, Time per sample:  0.2593s
# +---------------------------------------------+
# ==============================
#
#
# Making Directory: Results/Noisy/children_playing/-5
# =============================
# Starting Noisy Testing for: IHC_Extract_3.0 for children_playing noise at an SNR of -5
# > Initialising model: IHC_Extract_3.0
# **************************************************************
# Testing Best Model found at: Model Checkpoints/IHC_Extract_3.0 Checkpoints/best_IHC_Extract_3.0_checkpoint.pth.tar
# **************************************************************
# > Initialising model: IHC_Extract_3.0
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 237
# Evaluation accuracy:  0.1014, Phoneme Error Rate:  0.8986, Loss :  3.5918, Time:  61.8703s, Time per sample:  0.2611s
# +---------------------------------------------+
# ==============================
#
#
# Making Directory: Results/Noisy/children_playing/-10
# =============================
# Starting Noisy Testing for: IHC_Extract_3.0 for children_playing noise at an SNR of -10
# > Initialising model: IHC_Extract_3.0
# **************************************************************
# Testing Best Model found at: Model Checkpoints/IHC_Extract_3.0 Checkpoints/best_IHC_Extract_3.0_checkpoint.pth.tar
# **************************************************************
# > Initialising model: IHC_Extract_3.0
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 237
# Evaluation accuracy:  0.0775, Phoneme Error Rate:  0.9225, Loss :  3.9818, Time:  61.7654s, Time per sample:  0.2606s
# +---------------------------------------------+
# ==============================

# %% [markdown]
# ## K-Fold Model Stability Testing in Noise
#
# As robustness is the major issue with noise, the subsequent section will test the ability of the models saved at each k-fold, which were evaluated on the held out k-fold. These models were only trained and evaluated on clean data too. This thus tests the overall variability of the models, and the difference in how well they learn to generalise. All IHC models are tested here - not just the ones that performed well during the k-fold stability testing. This should confirm that leaving them out was a sound idea.
#
# ### Original Models Testing

# %%
noise_types=["White", 'air_conditioner', 'dog_bark', 'street_music', 'children_playing']

# %%
#original_models=[ "MelSimple_MLP", "MelSimple", "Wav2vec2", "Wav2vec2_80", "CPC_80", "CPC",  "SIG_Extract", "SIG_Extract_512", "SIG_Extract_2.0", "Whisper", "Whisper_80", "SIG_Extract_3.0"]

original_models=["Whisper", "Whisper_80", "SIG_Extract_3.0"]

    
for noise in noise_types:
    dir_kfold=Path("./Results/Noisy/k-Fold Stability/")
    dir_kfold.mkdir(parents=True, exist_ok=True)
    print("Making Directory: %s" % dir_kfold)
    dir_snr = Path("./Results/Noisy/k-Fold Stability/{}".format(noise))
    dir_snr.mkdir(parents=True, exist_ok=True)
    print("Making Directory: %s" % dir_snr)
    
    for snr in SNRs:
        dir_snr = Path("./Results/Noisy/k-Fold Stability/{}/{}".format(noise, snr))
        dir_snr.mkdir(parents=True, exist_ok=True)
        print("Making Directory: %s" % dir_snr)
        

        test_accuracies={}
        
        #Reload any old results so that we can continue training if required
        test_location='Results/Noisy/k-Fold Stability/{}/{}/original_models.pkl'.format(noise, snr)
        if(Path(test_location).is_file()):
            with open(test_location, 'rb') as f:
                test_accuracies = pickle.load(f)
            
        for model in original_models:
            print("=============================")
            print("Starting Noisy k-Fold Model Testing for: %s for %s noise at an SNR of %d" %(model, noise, snr))
            for k in range(5):
                
            
                #Test the model on the noisy dataset
                test_accu, test_loss, unique_phonemes, time=TrainEvalFunctions.test_best(model, distributed=False, Kfold_eval=True, kInt=k,  noise=True , noise_type= noise, SNR= snr)

                test_accuracies["{}-kFold-{}".format(model, k+1)]=test_accu

            print("==============================")
            print("")
            print("")

        #Saved for every SNR
        with open(test_location, 'wb') as f:
            pickle.dump(test_accuracies, f)
# Out:
# Making Directory: Results/Noisy/k-Fold Stability
# Making Directory: Results/Noisy/k-Fold Stability/White
# Making Directory: Results/Noisy/k-Fold Stability/White/30
# =============================
# Starting Noisy k-Fold Model Testing for: Whisper for White noise at an SNR of 30
# > Initialising model: Whisper
# **************************************************************
# Testing Best Model found at: Model Checkpoints/Whisper Checkpoints/kFold Eval 0/best_Whisper_checkpoint.pth.tar
# **************************************************************
# > Initialising model: Whisper
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 40
# Evaluation accuracy:  0.5453, Phoneme Error Rate:  0.4547, Loss :  0.9598, Time:  15.9626s, Time per sample:  0.3991s
# +---------------------------------------------+
# > Initialising model: Whisper
# **************************************************************
# Testing Best Model found at: Model Checkpoints/Whisper Checkpoints/kFold Eval 1/best_Whisper_checkpoint.pth.tar
# **************************************************************
# > Initialising model: Whisper
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 40
# Evaluation accuracy:  0.5495, Phoneme Error Rate:  0.4505, Loss :  0.9423, Time:  15.4877s, Time per sample:  0.3872s
# +---------------------------------------------+
# > Initialising model: Whisper
# **************************************************************
# Testing Best Model found at: Model Checkpoints/Whisper Checkpoints/kFold Eval 2/best_Whisper_checkpoint.pth.tar
# **************************************************************
# > Initialising model: Whisper
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 40
# Evaluation accuracy:  0.5525, Phoneme Error Rate:  0.4475, Loss :  0.9098, Time:  16.3871s, Time per sample:  0.4097s
# +---------------------------------------------+
# > Initialising model: Whisper
# **************************************************************
# Testing Best Model found at: Model Checkpoints/Whisper Checkpoints/kFold Eval 3/best_Whisper_checkpoint.pth.tar
# **************************************************************
# > Initialising model: Whisper
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 40
# Evaluation accuracy:  0.5512, Phoneme Error Rate:  0.4488, Loss :  0.9271, Time:  16.1715s, Time per sample:  0.4043s
# +---------------------------------------------+
# > Initialising model: Whisper
# **************************************************************
# Testing Best Model found at: Model Checkpoints/Whisper Checkpoints/kFold Eval 4/best_Whisper_checkpoint.pth.tar
# **************************************************************
# > Initialising model: Whisper
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 40
# Evaluation accuracy:  0.5400, Phoneme Error Rate:  0.4600, Loss :  0.9373, Time:  15.6082s, Time per sample:  0.3902s
# +---------------------------------------------+
# ==============================
#
#
# =============================
# Starting Noisy k-Fold Model Testing for: Whisper_80 for White noise at an SNR of 30
# > Initialising model: Whisper_80
# **************************************************************
# Testing Best Model found at: Model Checkpoints/Whisper_80 Checkpoints/kFold Eval 0/best_Whisper_80_checkpoint.pth.tar
# **************************************************************
# > Initialising model: Whisper_80
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 40
# Evaluation accuracy:  0.5433, Phoneme Error Rate:  0.4567, Loss :  0.8956, Time:  15.7821s, Time per sample:  0.3946s
# +---------------------------------------------+
# > Initialising model: Whisper_80
# **************************************************************
# Testing Best Model found at: Model Checkpoints/Whisper_80 Checkpoints/kFold Eval 1/best_Whisper_80_checkpoint.pth.tar
# **************************************************************
# > Initialising model: Whisper_80
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 40
# Evaluation accuracy:  0.5411, Phoneme Error Rate:  0.4589, Loss :  0.8955, Time:  16.8357s, Time per sample:  0.4209s
# +---------------------------------------------+
# > Initialising model: Whisper_80
# **************************************************************
# Testing Best Model found at: Model Checkpoints/Whisper_80 Checkpoints/kFold Eval 2/best_Whisper_80_checkpoint.pth.tar
# **************************************************************
# > Initialising model: Whisper_80
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 40
# Evaluation accuracy:  0.5483, Phoneme Error Rate:  0.4517, Loss :  0.8858, Time:  15.8647s, Time per sample:  0.3966s
# +---------------------------------------------+
# > Initialising model: Whisper_80
# **************************************************************
# Testing Best Model found at: Model Checkpoints/Whisper_80 Checkpoints/kFold Eval 3/best_Whisper_80_checkpoint.pth.tar
# **************************************************************
# > Initialising model: Whisper_80
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 40
# Evaluation accuracy:  0.5435, Phoneme Error Rate:  0.4565, Loss :  0.8876, Time:  15.8840s, Time per sample:  0.3971s
# +---------------------------------------------+
# > Initialising model: Whisper_80
# **************************************************************
# Testing Best Model found at: Model Checkpoints/Whisper_80 Checkpoints/kFold Eval 4/best_Whisper_80_checkpoint.pth.tar
# **************************************************************
# > Initialising model: Whisper_80
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 40
# Evaluation accuracy:  0.5422, Phoneme Error Rate:  0.4578, Loss :  0.8953, Time:  16.7189s, Time per sample:  0.4180s
# +---------------------------------------------+
# ==============================
#
#
# =============================
# Starting Noisy k-Fold Model Testing for: SIG_Extract_3.0 for White noise at an SNR of 30
# > Initialising model: SIG_Extract_3.0
# **************************************************************
# Testing Best Model found at: Model Checkpoints/SIG_Extract_3.0 Checkpoints/kFold Eval 0/best_SIG_Extract_3.0_checkpoint.pth.tar
# **************************************************************
# > Initialising model: SIG_Extract_3.0
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 237
# Evaluation accuracy:  0.4166, Phoneme Error Rate:  0.5834, Loss :  1.4206, Time:  10.5392s, Time per sample:  0.0445s
# +---------------------------------------------+
# > Initialising model: SIG_Extract_3.0
# **************************************************************
# Testing Best Model found at: Model Checkpoints/SIG_Extract_3.0 Checkpoints/kFold Eval 1/best_SIG_Extract_3.0_checkpoint.pth.tar
# **************************************************************
# > Initialising model: SIG_Extract_3.0
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 237
# Evaluation accuracy:  0.4738, Phoneme Error Rate:  0.5262, Loss :  1.3301, Time:  10.3353s, Time per sample:  0.0436s
# +---------------------------------------------+
# > Initialising model: SIG_Extract_3.0
# **************************************************************
# Testing Best Model found at: Model Checkpoints/SIG_Extract_3.0 Checkpoints/kFold Eval 2/best_SIG_Extract_3.0_checkpoint.pth.tar
# **************************************************************
# > Initialising model: SIG_Extract_3.0
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 237
# Evaluation accuracy:  0.5106, Phoneme Error Rate:  0.4894, Loss :  1.2881, Time:  10.3720s, Time per sample:  0.0438s
# +---------------------------------------------+
# > Initialising model: SIG_Extract_3.0
# **************************************************************
# Testing Best Model found at: Model Checkpoints/SIG_Extract_3.0 Checkpoints/kFold Eval 3/best_SIG_Extract_3.0_checkpoint.pth.tar
# **************************************************************
# > Initialising model: SIG_Extract_3.0
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 237
# Evaluation accuracy:  0.5310, Phoneme Error Rate:  0.4690, Loss :  1.2610, Time:  10.2946s, Time per sample:  0.0434s
# +---------------------------------------------+
# > Initialising model: SIG_Extract_3.0
# **************************************************************
# Testing Best Model found at: Model Checkpoints/SIG_Extract_3.0 Checkpoints/kFold Eval 4/best_SIG_Extract_3.0_checkpoint.pth.tar
# **************************************************************
# > Initialising model: SIG_Extract_3.0
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 237
# Evaluation accuracy:  0.4681, Phoneme Error Rate:  0.5319, Loss :  1.3646, Time:  10.6124s, Time per sample:  0.0448s
# +---------------------------------------------+
# ==============================
#
#
# Making Directory: Results/Noisy/k-Fold Stability/White/25
# =============================
# Starting Noisy k-Fold Model Testing for: Whisper for White noise at an SNR of 25
# > Initialising model: Whisper
# **************************************************************
# Testing Best Model found at: Model Checkpoints/Whisper Checkpoints/kFold Eval 0/best_Whisper_checkpoint.pth.tar
# **************************************************************
# > Initialising model: Whisper
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 40
# Evaluation accuracy:  0.4407, Phoneme Error Rate:  0.5593, Loss :  1.2345, Time:  15.6982s, Time per sample:  0.3925s
# +---------------------------------------------+
# > Initialising model: Whisper
# **************************************************************
# Testing Best Model found at: Model Checkpoints/Whisper Checkpoints/kFold Eval 1/best_Whisper_checkpoint.pth.tar
# **************************************************************
# > Initialising model: Whisper
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 40
# Evaluation accuracy:  0.4422, Phoneme Error Rate:  0.5578, Loss :  1.2327, Time:  15.9539s, Time per sample:  0.3988s
# +---------------------------------------------+
# > Initialising model: Whisper
# **************************************************************
# Testing Best Model found at: Model Checkpoints/Whisper Checkpoints/kFold Eval 2/best_Whisper_checkpoint.pth.tar
# **************************************************************
# > Initialising model: Whisper
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 40
# Evaluation accuracy:  0.4438, Phoneme Error Rate:  0.5562, Loss :  1.1840, Time:  15.9709s, Time per sample:  0.3993s
# +---------------------------------------------+
# > Initialising model: Whisper
# **************************************************************
# Testing Best Model found at: Model Checkpoints/Whisper Checkpoints/kFold Eval 3/best_Whisper_checkpoint.pth.tar
# **************************************************************
# > Initialising model: Whisper
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 40
# Evaluation accuracy:  0.4440, Phoneme Error Rate:  0.5560, Loss :  1.2092, Time:  16.5567s, Time per sample:  0.4139s
# +---------------------------------------------+
# > Initialising model: Whisper
# **************************************************************
# Testing Best Model found at: Model Checkpoints/Whisper Checkpoints/kFold Eval 4/best_Whisper_checkpoint.pth.tar
# **************************************************************
# > Initialising model: Whisper
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 40
# Evaluation accuracy:  0.4372, Phoneme Error Rate:  0.5628, Loss :  1.2057, Time:  15.8574s, Time per sample:  0.3964s
# +---------------------------------------------+
# ==============================
#
#
# =============================
# Starting Noisy k-Fold Model Testing for: Whisper_80 for White noise at an SNR of 25
# > Initialising model: Whisper_80
# **************************************************************
# Testing Best Model found at: Model Checkpoints/Whisper_80 Checkpoints/kFold Eval 0/best_Whisper_80_checkpoint.pth.tar
# **************************************************************
# > Initialising model: Whisper_80
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 40
# Evaluation accuracy:  0.4291, Phoneme Error Rate:  0.5709, Loss :  1.1598, Time:  15.8657s, Time per sample:  0.3966s
# +---------------------------------------------+
# > Initialising model: Whisper_80
# **************************************************************
# Testing Best Model found at: Model Checkpoints/Whisper_80 Checkpoints/kFold Eval 1/best_Whisper_80_checkpoint.pth.tar
# **************************************************************
# > Initialising model: Whisper_80
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 40
# Evaluation accuracy:  0.4312, Phoneme Error Rate:  0.5688, Loss :  1.1440, Time:  16.7338s, Time per sample:  0.4183s
# +---------------------------------------------+
# > Initialising model: Whisper_80
# **************************************************************
# Testing Best Model found at: Model Checkpoints/Whisper_80 Checkpoints/kFold Eval 2/best_Whisper_80_checkpoint.pth.tar
# **************************************************************
# > Initialising model: Whisper_80
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 40
# Evaluation accuracy:  0.4348, Phoneme Error Rate:  0.5652, Loss :  1.1479, Time:  16.0806s, Time per sample:  0.4020s
# +---------------------------------------------+
# > Initialising model: Whisper_80
# **************************************************************
# Testing Best Model found at: Model Checkpoints/Whisper_80 Checkpoints/kFold Eval 3/best_Whisper_80_checkpoint.pth.tar
# **************************************************************
# > Initialising model: Whisper_80
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 40
# Evaluation accuracy:  0.4296, Phoneme Error Rate:  0.5704, Loss :  1.1445, Time:  15.9254s, Time per sample:  0.3981s
# +---------------------------------------------+
# > Initialising model: Whisper_80
# **************************************************************
# Testing Best Model found at: Model Checkpoints/Whisper_80 Checkpoints/kFold Eval 4/best_Whisper_80_checkpoint.pth.tar
# **************************************************************
# > Initialising model: Whisper_80
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 40
# Evaluation accuracy:  0.4288, Phoneme Error Rate:  0.5712, Loss :  1.1503, Time:  17.5326s, Time per sample:  0.4383s
# +---------------------------------------------+
# ==============================
#
#
# =============================
# Starting Noisy k-Fold Model Testing for: SIG_Extract_3.0 for White noise at an SNR of 25
# > Initialising model: SIG_Extract_3.0
# **************************************************************
# Testing Best Model found at: Model Checkpoints/SIG_Extract_3.0 Checkpoints/kFold Eval 0/best_SIG_Extract_3.0_checkpoint.pth.tar
# **************************************************************
# > Initialising model: SIG_Extract_3.0
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 237
# Evaluation accuracy:  0.3042, Phoneme Error Rate:  0.6958, Loss :  1.7115, Time:  10.5586s, Time per sample:  0.0446s
# +---------------------------------------------+
# > Initialising model: SIG_Extract_3.0
# **************************************************************
# Testing Best Model found at: Model Checkpoints/SIG_Extract_3.0 Checkpoints/kFold Eval 1/best_SIG_Extract_3.0_checkpoint.pth.tar
# **************************************************************
# > Initialising model: SIG_Extract_3.0
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 237
# Evaluation accuracy:  0.3403, Phoneme Error Rate:  0.6597, Loss :  1.5617, Time:  10.5327s, Time per sample:  0.0444s
# +---------------------------------------------+
# > Initialising model: SIG_Extract_3.0
# **************************************************************
# Testing Best Model found at: Model Checkpoints/SIG_Extract_3.0 Checkpoints/kFold Eval 2/best_SIG_Extract_3.0_checkpoint.pth.tar
# **************************************************************
# > Initialising model: SIG_Extract_3.0
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 237
# Evaluation accuracy:  0.3647, Phoneme Error Rate:  0.6353, Loss :  1.5158, Time:  10.5351s, Time per sample:  0.0445s
# +---------------------------------------------+
# > Initialising model: SIG_Extract_3.0
# **************************************************************
# Testing Best Model found at: Model Checkpoints/SIG_Extract_3.0 Checkpoints/kFold Eval 3/best_SIG_Extract_3.0_checkpoint.pth.tar
# **************************************************************
# > Initialising model: SIG_Extract_3.0
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 237
# Evaluation accuracy:  0.4306, Phoneme Error Rate:  0.5694, Loss :  1.4250, Time:  10.4837s, Time per sample:  0.0442s
# +---------------------------------------------+
# > Initialising model: SIG_Extract_3.0
# **************************************************************
# Testing Best Model found at: Model Checkpoints/SIG_Extract_3.0 Checkpoints/kFold Eval 4/best_SIG_Extract_3.0_checkpoint.pth.tar
# **************************************************************
# > Initialising model: SIG_Extract_3.0
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 237
# Evaluation accuracy:  0.3163, Phoneme Error Rate:  0.6837, Loss :  1.6351, Time:  10.7626s, Time per sample:  0.0454s
# +---------------------------------------------+
# ==============================
#
#
# Making Directory: Results/Noisy/k-Fold Stability/White/20
# =============================
# Starting Noisy k-Fold Model Testing for: Whisper for White noise at an SNR of 20
# > Initialising model: Whisper
# **************************************************************
# Testing Best Model found at: Model Checkpoints/Whisper Checkpoints/kFold Eval 0/best_Whisper_checkpoint.pth.tar
# **************************************************************
# > Initialising model: Whisper
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 40
# Evaluation accuracy:  0.3617, Phoneme Error Rate:  0.6383, Loss :  1.6589, Time:  16.0684s, Time per sample:  0.4017s
# +---------------------------------------------+
# > Initialising model: Whisper
# **************************************************************
# Testing Best Model found at: Model Checkpoints/Whisper Checkpoints/kFold Eval 1/best_Whisper_checkpoint.pth.tar
# **************************************************************
# > Initialising model: Whisper
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 40
# Evaluation accuracy:  0.3640, Phoneme Error Rate:  0.6360, Loss :  1.6606, Time:  15.9531s, Time per sample:  0.3988s
# +---------------------------------------------+
# > Initialising model: Whisper
# **************************************************************
# Testing Best Model found at: Model Checkpoints/Whisper Checkpoints/kFold Eval 2/best_Whisper_checkpoint.pth.tar
# **************************************************************
# > Initialising model: Whisper
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 40
# Evaluation accuracy:  0.3621, Phoneme Error Rate:  0.6379, Loss :  1.6125, Time:  16.9128s, Time per sample:  0.4228s
# +---------------------------------------------+
# > Initialising model: Whisper
# **************************************************************
# Testing Best Model found at: Model Checkpoints/Whisper Checkpoints/kFold Eval 3/best_Whisper_checkpoint.pth.tar
# **************************************************************
# > Initialising model: Whisper
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 40
# Evaluation accuracy:  0.3629, Phoneme Error Rate:  0.6371, Loss :  1.6524, Time:  15.9444s, Time per sample:  0.3986s
# +---------------------------------------------+
# > Initialising model: Whisper
# **************************************************************
# Testing Best Model found at: Model Checkpoints/Whisper Checkpoints/kFold Eval 4/best_Whisper_checkpoint.pth.tar
# **************************************************************
# > Initialising model: Whisper
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 40
# Evaluation accuracy:  0.3626, Phoneme Error Rate:  0.6374, Loss :  1.6226, Time:  16.2411s, Time per sample:  0.4060s
# +---------------------------------------------+
# ==============================
#
#
# =============================
# Starting Noisy k-Fold Model Testing for: Whisper_80 for White noise at an SNR of 20
# > Initialising model: Whisper_80
# **************************************************************
# Testing Best Model found at: Model Checkpoints/Whisper_80 Checkpoints/kFold Eval 0/best_Whisper_80_checkpoint.pth.tar
# **************************************************************
# > Initialising model: Whisper_80
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 40
# Evaluation accuracy:  0.3453, Phoneme Error Rate:  0.6547, Loss :  1.5872, Time:  16.7552s, Time per sample:  0.4189s
# +---------------------------------------------+
# > Initialising model: Whisper_80
# **************************************************************
# Testing Best Model found at: Model Checkpoints/Whisper_80 Checkpoints/kFold Eval 1/best_Whisper_80_checkpoint.pth.tar
# **************************************************************
# > Initialising model: Whisper_80
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 40
# Evaluation accuracy:  0.3519, Phoneme Error Rate:  0.6481, Loss :  1.5055, Time:  16.2086s, Time per sample:  0.4052s
# +---------------------------------------------+
# > Initialising model: Whisper_80
# **************************************************************
# Testing Best Model found at: Model Checkpoints/Whisper_80 Checkpoints/kFold Eval 2/best_Whisper_80_checkpoint.pth.tar
# **************************************************************
# > Initialising model: Whisper_80
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 40
# Evaluation accuracy:  0.3432, Phoneme Error Rate:  0.6568, Loss :  1.5903, Time:  15.9167s, Time per sample:  0.3979s
# +---------------------------------------------+
# > Initialising model: Whisper_80
# **************************************************************
# Testing Best Model found at: Model Checkpoints/Whisper_80 Checkpoints/kFold Eval 3/best_Whisper_80_checkpoint.pth.tar
# **************************************************************
# > Initialising model: Whisper_80
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 40
# Evaluation accuracy:  0.3457, Phoneme Error Rate:  0.6543, Loss :  1.5567, Time:  16.8253s, Time per sample:  0.4206s
# +---------------------------------------------+
# > Initialising model: Whisper_80
# **************************************************************
# Testing Best Model found at: Model Checkpoints/Whisper_80 Checkpoints/kFold Eval 4/best_Whisper_80_checkpoint.pth.tar
# **************************************************************
# > Initialising model: Whisper_80
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 40
# Evaluation accuracy:  0.3473, Phoneme Error Rate:  0.6527, Loss :  1.5769, Time:  16.2229s, Time per sample:  0.4056s
# +---------------------------------------------+
# ==============================
#
#
# =============================
# Starting Noisy k-Fold Model Testing for: SIG_Extract_3.0 for White noise at an SNR of 20
# > Initialising model: SIG_Extract_3.0
# **************************************************************
# Testing Best Model found at: Model Checkpoints/SIG_Extract_3.0 Checkpoints/kFold Eval 0/best_SIG_Extract_3.0_checkpoint.pth.tar
# **************************************************************
# > Initialising model: SIG_Extract_3.0
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 237
# Evaluation accuracy:  0.2633, Phoneme Error Rate:  0.7367, Loss :  1.9378, Time:  10.6694s, Time per sample:  0.0450s
# +---------------------------------------------+
# > Initialising model: SIG_Extract_3.0
# **************************************************************
# Testing Best Model found at: Model Checkpoints/SIG_Extract_3.0 Checkpoints/kFold Eval 1/best_SIG_Extract_3.0_checkpoint.pth.tar
# **************************************************************
# > Initialising model: SIG_Extract_3.0
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 237
# Evaluation accuracy:  0.2819, Phoneme Error Rate:  0.7181, Loss :  1.8718, Time:  10.5277s, Time per sample:  0.0444s
# +---------------------------------------------+
# > Initialising model: SIG_Extract_3.0
# **************************************************************
# Testing Best Model found at: Model Checkpoints/SIG_Extract_3.0 Checkpoints/kFold Eval 2/best_SIG_Extract_3.0_checkpoint.pth.tar
# **************************************************************
# > Initialising model: SIG_Extract_3.0
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 237
# Evaluation accuracy:  0.2697, Phoneme Error Rate:  0.7303, Loss :  1.8422, Time:  10.6454s, Time per sample:  0.0449s
# +---------------------------------------------+
# > Initialising model: SIG_Extract_3.0
# **************************************************************
# Testing Best Model found at: Model Checkpoints/SIG_Extract_3.0 Checkpoints/kFold Eval 3/best_SIG_Extract_3.0_checkpoint.pth.tar
# **************************************************************
# > Initialising model: SIG_Extract_3.0
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 237
# Evaluation accuracy:  0.3126, Phoneme Error Rate:  0.6874, Loss :  1.6943, Time:  10.7743s, Time per sample:  0.0455s
# +---------------------------------------------+
# > Initialising model: SIG_Extract_3.0
# **************************************************************
# Testing Best Model found at: Model Checkpoints/SIG_Extract_3.0 Checkpoints/kFold Eval 4/best_SIG_Extract_3.0_checkpoint.pth.tar
# **************************************************************
# > Initialising model: SIG_Extract_3.0
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 237
# Evaluation accuracy:  0.2681, Phoneme Error Rate:  0.7319, Loss :  1.8893, Time:  10.6579s, Time per sample:  0.0450s
# +---------------------------------------------+
# ==============================
#
#
# Making Directory: Results/Noisy/k-Fold Stability/White/15
# =============================
# Starting Noisy k-Fold Model Testing for: Whisper for White noise at an SNR of 15
# > Initialising model: Whisper
# **************************************************************
# Testing Best Model found at: Model Checkpoints/Whisper Checkpoints/kFold Eval 0/best_Whisper_checkpoint.pth.tar
# **************************************************************
# > Initialising model: Whisper
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 40
# Evaluation accuracy:  0.2998, Phoneme Error Rate:  0.7002, Loss :  2.2333, Time:  16.0382s, Time per sample:  0.4010s
# +---------------------------------------------+
# > Initialising model: Whisper
# **************************************************************
# Testing Best Model found at: Model Checkpoints/Whisper Checkpoints/kFold Eval 1/best_Whisper_checkpoint.pth.tar
# **************************************************************
# > Initialising model: Whisper
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 40
# Evaluation accuracy:  0.3048, Phoneme Error Rate:  0.6952, Loss :  2.1422, Time:  16.2834s, Time per sample:  0.4071s
# +---------------------------------------------+
# > Initialising model: Whisper
# **************************************************************
# Testing Best Model found at: Model Checkpoints/Whisper Checkpoints/kFold Eval 2/best_Whisper_checkpoint.pth.tar
# **************************************************************
# > Initialising model: Whisper
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 40
# Evaluation accuracy:  0.2981, Phoneme Error Rate:  0.7019, Loss :  2.1162, Time:  16.7430s, Time per sample:  0.4186s
# +---------------------------------------------+
# > Initialising model: Whisper
# **************************************************************
# Testing Best Model found at: Model Checkpoints/Whisper Checkpoints/kFold Eval 3/best_Whisper_checkpoint.pth.tar
# **************************************************************
# > Initialising model: Whisper
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 40
# Evaluation accuracy:  0.3035, Phoneme Error Rate:  0.6965, Loss :  2.1598, Time:  16.1235s, Time per sample:  0.4031s
# +---------------------------------------------+
# > Initialising model: Whisper
# **************************************************************
# Testing Best Model found at: Model Checkpoints/Whisper Checkpoints/kFold Eval 4/best_Whisper_checkpoint.pth.tar
# **************************************************************
# > Initialising model: Whisper
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 40
# Evaluation accuracy:  0.3032, Phoneme Error Rate:  0.6968, Loss :  2.1725, Time:  16.5549s, Time per sample:  0.4139s
# +---------------------------------------------+
# ==============================
#
#
# =============================
# Starting Noisy k-Fold Model Testing for: Whisper_80 for White noise at an SNR of 15
# > Initialising model: Whisper_80
# **************************************************************
# Testing Best Model found at: Model Checkpoints/Whisper_80 Checkpoints/kFold Eval 0/best_Whisper_80_checkpoint.pth.tar
# **************************************************************
# > Initialising model: Whisper_80
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 40
# Evaluation accuracy:  0.2868, Phoneme Error Rate:  0.7132, Loss :  2.0583, Time:  16.8442s, Time per sample:  0.4211s
# +---------------------------------------------+
# > Initialising model: Whisper_80
# **************************************************************
# Testing Best Model found at: Model Checkpoints/Whisper_80 Checkpoints/kFold Eval 1/best_Whisper_80_checkpoint.pth.tar
# **************************************************************
# > Initialising model: Whisper_80
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 40
# Evaluation accuracy:  0.2889, Phoneme Error Rate:  0.7111, Loss :  1.9104, Time:  16.2075s, Time per sample:  0.4052s
# +---------------------------------------------+
# > Initialising model: Whisper_80
# **************************************************************
# Testing Best Model found at: Model Checkpoints/Whisper_80 Checkpoints/kFold Eval 2/best_Whisper_80_checkpoint.pth.tar
# **************************************************************
# > Initialising model: Whisper_80
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 40
# Evaluation accuracy:  0.2824, Phoneme Error Rate:  0.7176, Loss :  2.0988, Time:  16.0976s, Time per sample:  0.4024s
# +---------------------------------------------+
# > Initialising model: Whisper_80
# **************************************************************
# Testing Best Model found at: Model Checkpoints/Whisper_80 Checkpoints/kFold Eval 3/best_Whisper_80_checkpoint.pth.tar
# **************************************************************
# > Initialising model: Whisper_80
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 40
# Evaluation accuracy:  0.2845, Phoneme Error Rate:  0.7155, Loss :  1.9985, Time:  17.2673s, Time per sample:  0.4317s
# +---------------------------------------------+
# > Initialising model: Whisper_80
# **************************************************************
# Testing Best Model found at: Model Checkpoints/Whisper_80 Checkpoints/kFold Eval 4/best_Whisper_80_checkpoint.pth.tar
# **************************************************************
# > Initialising model: Whisper_80
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 40
# Evaluation accuracy:  0.2807, Phoneme Error Rate:  0.7193, Loss :  2.1870, Time:  16.2737s, Time per sample:  0.4068s
# +---------------------------------------------+
# ==============================
#
#
# =============================
# Starting Noisy k-Fold Model Testing for: SIG_Extract_3.0 for White noise at an SNR of 15
# > Initialising model: SIG_Extract_3.0
# **************************************************************
# Testing Best Model found at: Model Checkpoints/SIG_Extract_3.0 Checkpoints/kFold Eval 0/best_SIG_Extract_3.0_checkpoint.pth.tar
# **************************************************************
# > Initialising model: SIG_Extract_3.0
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 237
# Evaluation accuracy:  0.2241, Phoneme Error Rate:  0.7759, Loss :  2.2670, Time:  10.7221s, Time per sample:  0.0452s
# +---------------------------------------------+
# > Initialising model: SIG_Extract_3.0
# **************************************************************
# Testing Best Model found at: Model Checkpoints/SIG_Extract_3.0 Checkpoints/kFold Eval 1/best_SIG_Extract_3.0_checkpoint.pth.tar
# **************************************************************
# > Initialising model: SIG_Extract_3.0
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 237
# Evaluation accuracy:  0.2388, Phoneme Error Rate:  0.7612, Loss :  2.3063, Time:  10.7436s, Time per sample:  0.0453s
# +---------------------------------------------+
# > Initialising model: SIG_Extract_3.0
# **************************************************************
# Testing Best Model found at: Model Checkpoints/SIG_Extract_3.0 Checkpoints/kFold Eval 2/best_SIG_Extract_3.0_checkpoint.pth.tar
# **************************************************************
# > Initialising model: SIG_Extract_3.0
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 237
# Evaluation accuracy:  0.2295, Phoneme Error Rate:  0.7705, Loss :  2.2157, Time:  11.0216s, Time per sample:  0.0465s
# +---------------------------------------------+
# > Initialising model: SIG_Extract_3.0
# **************************************************************
# Testing Best Model found at: Model Checkpoints/SIG_Extract_3.0 Checkpoints/kFold Eval 3/best_SIG_Extract_3.0_checkpoint.pth.tar
# **************************************************************
# > Initialising model: SIG_Extract_3.0
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 237
# Evaluation accuracy:  0.2474, Phoneme Error Rate:  0.7526, Loss :  2.0434, Time:  10.6430s, Time per sample:  0.0449s
# +---------------------------------------------+
# > Initialising model: SIG_Extract_3.0
# **************************************************************
# Testing Best Model found at: Model Checkpoints/SIG_Extract_3.0 Checkpoints/kFold Eval 4/best_SIG_Extract_3.0_checkpoint.pth.tar
# **************************************************************
# > Initialising model: SIG_Extract_3.0
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 237
# Evaluation accuracy:  0.2371, Phoneme Error Rate:  0.7629, Loss :  2.2027, Time:  10.6351s, Time per sample:  0.0449s
# +---------------------------------------------+
# ==============================
#
#
# Making Directory: Results/Noisy/k-Fold Stability/White/10
# =============================
# Starting Noisy k-Fold Model Testing for: Whisper for White noise at an SNR of 10
# > Initialising model: Whisper
# **************************************************************
# Testing Best Model found at: Model Checkpoints/Whisper Checkpoints/kFold Eval 0/best_Whisper_checkpoint.pth.tar
# **************************************************************
# > Initialising model: Whisper
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 40
# Evaluation accuracy:  0.2334, Phoneme Error Rate:  0.7666, Loss :  3.2455, Time:  15.8768s, Time per sample:  0.3969s
# +---------------------------------------------+
# > Initialising model: Whisper
# **************************************************************
# Testing Best Model found at: Model Checkpoints/Whisper Checkpoints/kFold Eval 1/best_Whisper_checkpoint.pth.tar
# **************************************************************
# > Initialising model: Whisper
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 40
# Evaluation accuracy:  0.2505, Phoneme Error Rate:  0.7495, Loss :  2.9145, Time:  17.1053s, Time per sample:  0.4276s
# +---------------------------------------------+
# > Initialising model: Whisper
# **************************************************************
# Testing Best Model found at: Model Checkpoints/Whisper Checkpoints/kFold Eval 2/best_Whisper_checkpoint.pth.tar
# **************************************************************
# > Initialising model: Whisper
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 40
# Evaluation accuracy:  0.2364, Phoneme Error Rate:  0.7636, Loss :  2.7950, Time:  16.0296s, Time per sample:  0.4007s
# +---------------------------------------------+
# > Initialising model: Whisper
# **************************************************************
# Testing Best Model found at: Model Checkpoints/Whisper Checkpoints/kFold Eval 3/best_Whisper_checkpoint.pth.tar
# **************************************************************
# > Initialising model: Whisper
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 40
# Evaluation accuracy:  0.2430, Phoneme Error Rate:  0.7570, Loss :  2.7505, Time:  16.2278s, Time per sample:  0.4057s
# +---------------------------------------------+
# > Initialising model: Whisper
# **************************************************************
# Testing Best Model found at: Model Checkpoints/Whisper Checkpoints/kFold Eval 4/best_Whisper_checkpoint.pth.tar
# **************************************************************
# > Initialising model: Whisper
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 40
# Evaluation accuracy:  0.2415, Phoneme Error Rate:  0.7585, Loss :  3.0537, Time:  16.8792s, Time per sample:  0.4220s
# +---------------------------------------------+
# ==============================
#
#
# =============================
# Starting Noisy k-Fold Model Testing for: Whisper_80 for White noise at an SNR of 10
# > Initialising model: Whisper_80
# **************************************************************
# Testing Best Model found at: Model Checkpoints/Whisper_80 Checkpoints/kFold Eval 0/best_Whisper_80_checkpoint.pth.tar
# **************************************************************
# > Initialising model: Whisper_80
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 40
# Evaluation accuracy:  0.2229, Phoneme Error Rate:  0.7771, Loss :  2.5411, Time:  16.6064s, Time per sample:  0.4152s
# +---------------------------------------------+
# > Initialising model: Whisper_80
# **************************************************************
# Testing Best Model found at: Model Checkpoints/Whisper_80 Checkpoints/kFold Eval 1/best_Whisper_80_checkpoint.pth.tar
# **************************************************************
# > Initialising model: Whisper_80
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 40
# Evaluation accuracy:  0.2218, Phoneme Error Rate:  0.7782, Loss :  2.4438, Time:  15.9570s, Time per sample:  0.3989s
# +---------------------------------------------+
# > Initialising model: Whisper_80
# **************************************************************
# Testing Best Model found at: Model Checkpoints/Whisper_80 Checkpoints/kFold Eval 2/best_Whisper_80_checkpoint.pth.tar
# **************************************************************
# > Initialising model: Whisper_80
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 40
# Evaluation accuracy:  0.2233, Phoneme Error Rate:  0.7767, Loss :  2.4812, Time:  16.6020s, Time per sample:  0.4150s
# +---------------------------------------------+
# > Initialising model: Whisper_80
# **************************************************************
# Testing Best Model found at: Model Checkpoints/Whisper_80 Checkpoints/kFold Eval 3/best_Whisper_80_checkpoint.pth.tar
# **************************************************************
# > Initialising model: Whisper_80
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 40
# Evaluation accuracy:  0.2167, Phoneme Error Rate:  0.7833, Loss :  2.6089, Time:  16.6914s, Time per sample:  0.4173s
# +---------------------------------------------+
# > Initialising model: Whisper_80
# **************************************************************
# Testing Best Model found at: Model Checkpoints/Whisper_80 Checkpoints/kFold Eval 4/best_Whisper_80_checkpoint.pth.tar
# **************************************************************
# > Initialising model: Whisper_80
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 40
# Evaluation accuracy:  0.2043, Phoneme Error Rate:  0.7957, Loss :  3.0341, Time:  16.4972s, Time per sample:  0.4124s
# +---------------------------------------------+
# ==============================
#
#
# =============================
# Starting Noisy k-Fold Model Testing for: SIG_Extract_3.0 for White noise at an SNR of 10
# > Initialising model: SIG_Extract_3.0
# **************************************************************
# Testing Best Model found at: Model Checkpoints/SIG_Extract_3.0 Checkpoints/kFold Eval 0/best_SIG_Extract_3.0_checkpoint.pth.tar
# **************************************************************
# > Initialising model: SIG_Extract_3.0
# > Setting: Test Mode
# ...
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 40
# Evaluation accuracy:  0.0716, Phoneme Error Rate:  0.9284, Loss :  110.5844, Time:  16.1012s, Time per sample:  0.4025s
# +---------------------------------------------+
# > Initialising model: Whisper_80
# **************************************************************
# Testing Best Model found at: Model Checkpoints/Whisper_80 Checkpoints/kFold Eval 2/best_Whisper_80_checkpoint.pth.tar
# **************************************************************
# > Initialising model: Whisper_80
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 40
# Evaluation accuracy:  0.0691, Phoneme Error Rate:  0.9309, Loss :  150.7907, Time:  16.8367s, Time per sample:  0.4209s
# +---------------------------------------------+
# > Initialising model: Whisper_80
# **************************************************************
# Testing Best Model found at: Model Checkpoints/Whisper_80 Checkpoints/kFold Eval 3/best_Whisper_80_checkpoint.pth.tar
# **************************************************************
# > Initialising model: Whisper_80
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 40
# Evaluation accuracy:  0.0684, Phoneme Error Rate:  0.9316, Loss :  153.0342, Time:  15.8953s, Time per sample:  0.3974s
# +---------------------------------------------+
# > Initialising model: Whisper_80
# **************************************************************
# Testing Best Model found at: Model Checkpoints/Whisper_80 Checkpoints/kFold Eval 4/best_Whisper_80_checkpoint.pth.tar
# **************************************************************
# > Initialising model: Whisper_80
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 40
# Evaluation accuracy:  0.0711, Phoneme Error Rate:  0.9289, Loss :  147.6773, Time:  15.8945s, Time per sample:  0.3974s
# +---------------------------------------------+
# ==============================
#
#
# =============================
# Starting Noisy k-Fold Model Testing for: SIG_Extract_3.0 for children_playing noise at an SNR of -5
# > Initialising model: SIG_Extract_3.0
# **************************************************************
# Testing Best Model found at: Model Checkpoints/SIG_Extract_3.0 Checkpoints/kFold Eval 0/best_SIG_Extract_3.0_checkpoint.pth.tar
# **************************************************************
# > Initialising model: SIG_Extract_3.0
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 237
# Evaluation accuracy:  0.0609, Phoneme Error Rate:  0.9391, Loss :  6.0732, Time:  11.1788s, Time per sample:  0.0472s
# +---------------------------------------------+
# > Initialising model: SIG_Extract_3.0
# **************************************************************
# Testing Best Model found at: Model Checkpoints/SIG_Extract_3.0 Checkpoints/kFold Eval 1/best_SIG_Extract_3.0_checkpoint.pth.tar
# **************************************************************
# > Initialising model: SIG_Extract_3.0
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 237
# Evaluation accuracy:  0.0647, Phoneme Error Rate:  0.9353, Loss :  5.5480, Time:  10.9838s, Time per sample:  0.0463s
# +---------------------------------------------+
# > Initialising model: SIG_Extract_3.0
# **************************************************************
# Testing Best Model found at: Model Checkpoints/SIG_Extract_3.0 Checkpoints/kFold Eval 2/best_SIG_Extract_3.0_checkpoint.pth.tar
# **************************************************************
# > Initialising model: SIG_Extract_3.0
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 237
# Evaluation accuracy:  0.0747, Phoneme Error Rate:  0.9253, Loss :  6.9264, Time:  10.9361s, Time per sample:  0.0461s
# +---------------------------------------------+
# > Initialising model: SIG_Extract_3.0
# **************************************************************
# Testing Best Model found at: Model Checkpoints/SIG_Extract_3.0 Checkpoints/kFold Eval 3/best_SIG_Extract_3.0_checkpoint.pth.tar
# **************************************************************
# > Initialising model: SIG_Extract_3.0
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 237
# Evaluation accuracy:  0.1487, Phoneme Error Rate:  0.8513, Loss :  3.3348, Time:  10.8995s, Time per sample:  0.0460s
# +---------------------------------------------+
# > Initialising model: SIG_Extract_3.0
# **************************************************************
# Testing Best Model found at: Model Checkpoints/SIG_Extract_3.0 Checkpoints/kFold Eval 4/best_SIG_Extract_3.0_checkpoint.pth.tar
# **************************************************************
# > Initialising model: SIG_Extract_3.0
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 237
# Evaluation accuracy:  0.0657, Phoneme Error Rate:  0.9343, Loss :  7.1827, Time:  10.9434s, Time per sample:  0.0462s
# +---------------------------------------------+
# ==============================
#
#
# Making Directory: Results/Noisy/k-Fold Stability/children_playing/-10
# =============================
# Starting Noisy k-Fold Model Testing for: Whisper for children_playing noise at an SNR of -10
# > Initialising model: Whisper
# **************************************************************
# Testing Best Model found at: Model Checkpoints/Whisper Checkpoints/kFold Eval 0/best_Whisper_checkpoint.pth.tar
# **************************************************************
# > Initialising model: Whisper
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 40
# Evaluation accuracy:  0.0492, Phoneme Error Rate:  0.9508, Loss :  1890.5109, Time:  17.0863s, Time per sample:  0.4272s
# +---------------------------------------------+
# > Initialising model: Whisper
# **************************************************************
# Testing Best Model found at: Model Checkpoints/Whisper Checkpoints/kFold Eval 1/best_Whisper_checkpoint.pth.tar
# **************************************************************
# > Initialising model: Whisper
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 40
# Evaluation accuracy:  0.0545, Phoneme Error Rate:  0.9455, Loss :  2102.7443, Time:  15.8620s, Time per sample:  0.3965s
# +---------------------------------------------+
# > Initialising model: Whisper
# **************************************************************
# Testing Best Model found at: Model Checkpoints/Whisper Checkpoints/kFold Eval 2/best_Whisper_checkpoint.pth.tar
# **************************************************************
# > Initialising model: Whisper
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 40
# Evaluation accuracy:  0.0616, Phoneme Error Rate:  0.9384, Loss :  1248.8171, Time:  15.9195s, Time per sample:  0.3980s
# +---------------------------------------------+
# > Initialising model: Whisper
# **************************************************************
# Testing Best Model found at: Model Checkpoints/Whisper Checkpoints/kFold Eval 3/best_Whisper_checkpoint.pth.tar
# **************************************************************
# > Initialising model: Whisper
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 40
# Evaluation accuracy:  0.0671, Phoneme Error Rate:  0.9329, Loss :  1260.7492, Time:  17.0251s, Time per sample:  0.4256s
# +---------------------------------------------+
# > Initialising model: Whisper
# **************************************************************
# Testing Best Model found at: Model Checkpoints/Whisper Checkpoints/kFold Eval 4/best_Whisper_checkpoint.pth.tar
# **************************************************************
# > Initialising model: Whisper
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 40
# Evaluation accuracy:  0.0416, Phoneme Error Rate:  0.9584, Loss :  1402.7701, Time:  15.7794s, Time per sample:  0.3945s
# +---------------------------------------------+
# ==============================
#
#
# =============================
# Starting Noisy k-Fold Model Testing for: Whisper_80 for children_playing noise at an SNR of -10
# > Initialising model: Whisper_80
# **************************************************************
# Testing Best Model found at: Model Checkpoints/Whisper_80 Checkpoints/kFold Eval 0/best_Whisper_80_checkpoint.pth.tar
# **************************************************************
# > Initialising model: Whisper_80
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 40
# Evaluation accuracy:  0.0474, Phoneme Error Rate:  0.9526, Loss :  650.0013, Time:  15.7788s, Time per sample:  0.3945s
# +---------------------------------------------+
# > Initialising model: Whisper_80
# **************************************************************
# Testing Best Model found at: Model Checkpoints/Whisper_80 Checkpoints/kFold Eval 1/best_Whisper_80_checkpoint.pth.tar
# **************************************************************
# > Initialising model: Whisper_80
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 40
# Evaluation accuracy:  0.0540, Phoneme Error Rate:  0.9460, Loss :  362.4429, Time:  16.8228s, Time per sample:  0.4206s
# +---------------------------------------------+
# > Initialising model: Whisper_80
# **************************************************************
# Testing Best Model found at: Model Checkpoints/Whisper_80 Checkpoints/kFold Eval 2/best_Whisper_80_checkpoint.pth.tar
# **************************************************************
# > Initialising model: Whisper_80
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 40
# Evaluation accuracy:  0.0480, Phoneme Error Rate:  0.9520, Loss :  497.8118, Time:  16.1152s, Time per sample:  0.4029s
# +---------------------------------------------+
# > Initialising model: Whisper_80
# **************************************************************
# Testing Best Model found at: Model Checkpoints/Whisper_80 Checkpoints/kFold Eval 3/best_Whisper_80_checkpoint.pth.tar
# **************************************************************
# > Initialising model: Whisper_80
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 40
# Evaluation accuracy:  0.0470, Phoneme Error Rate:  0.9530, Loss :  517.4026, Time:  15.9416s, Time per sample:  0.3985s
# +---------------------------------------------+
# > Initialising model: Whisper_80
# **************************************************************
# Testing Best Model found at: Model Checkpoints/Whisper_80 Checkpoints/kFold Eval 4/best_Whisper_80_checkpoint.pth.tar
# **************************************************************
# > Initialising model: Whisper_80
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 40
# Evaluation accuracy:  0.0494, Phoneme Error Rate:  0.9506, Loss :  478.7869, Time:  17.5588s, Time per sample:  0.4390s
# +---------------------------------------------+
# ==============================
#
#
# =============================
# Starting Noisy k-Fold Model Testing for: SIG_Extract_3.0 for children_playing noise at an SNR of -10
# > Initialising model: SIG_Extract_3.0
# **************************************************************
# Testing Best Model found at: Model Checkpoints/SIG_Extract_3.0 Checkpoints/kFold Eval 0/best_SIG_Extract_3.0_checkpoint.pth.tar
# **************************************************************
# > Initialising model: SIG_Extract_3.0
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 237
# Evaluation accuracy:  0.0483, Phoneme Error Rate:  0.9517, Loss :  6.3955, Time:  11.3503s, Time per sample:  0.0479s
# +---------------------------------------------+
# > Initialising model: SIG_Extract_3.0
# **************************************************************
# Testing Best Model found at: Model Checkpoints/SIG_Extract_3.0 Checkpoints/kFold Eval 1/best_SIG_Extract_3.0_checkpoint.pth.tar
# **************************************************************
# > Initialising model: SIG_Extract_3.0
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 237
# Evaluation accuracy:  0.0485, Phoneme Error Rate:  0.9515, Loss :  5.9931, Time:  11.3523s, Time per sample:  0.0479s
# +---------------------------------------------+
# > Initialising model: SIG_Extract_3.0
# **************************************************************
# Testing Best Model found at: Model Checkpoints/SIG_Extract_3.0 Checkpoints/kFold Eval 2/best_SIG_Extract_3.0_checkpoint.pth.tar
# **************************************************************
# > Initialising model: SIG_Extract_3.0
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 237
# Evaluation accuracy:  0.0616, Phoneme Error Rate:  0.9384, Loss :  7.3027, Time:  11.3248s, Time per sample:  0.0478s
# +---------------------------------------------+
# > Initialising model: SIG_Extract_3.0
# **************************************************************
# Testing Best Model found at: Model Checkpoints/SIG_Extract_3.0 Checkpoints/kFold Eval 3/best_SIG_Extract_3.0_checkpoint.pth.tar
# **************************************************************
# > Initialising model: SIG_Extract_3.0
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 237
# Evaluation accuracy:  0.1276, Phoneme Error Rate:  0.8724, Loss :  3.5980, Time:  11.1903s, Time per sample:  0.0472s
# +---------------------------------------------+
# > Initialising model: SIG_Extract_3.0
# **************************************************************
# Testing Best Model found at: Model Checkpoints/SIG_Extract_3.0 Checkpoints/kFold Eval 4/best_SIG_Extract_3.0_checkpoint.pth.tar
# **************************************************************
# > Initialising model: SIG_Extract_3.0
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 237
# Evaluation accuracy:  0.0509, Phoneme Error Rate:  0.9491, Loss :  7.7034, Time:  11.3736s, Time per sample:  0.0480s
# +---------------------------------------------+
# ==============================

# %% [markdown]
# ### IHC Models Testing

# %%
#IHC_models=["IHC_Cpc", "IHC_Wav2vec2", "IHC_Extract_512", "IHC_Extract", "IHC_Cpc_80", "IHC_Wav2vec2_80",   "IHC_Extract_2.0", "IHC_Extract_3.0"]

IHC_models=["IHC_Extract_3.0"]
    
for noise in noise_types:
    dir_kfold=Path("./Results/Noisy/k-Fold Stability/")
    dir_kfold.mkdir(parents=True, exist_ok=True)
    print("Making Directory: %s" % dir_kfold)
    dir_snr = Path("./Results/Noisy/k-Fold Stability/{}".format(noise))
    dir_snr.mkdir(parents=True, exist_ok=True)
    print("Making Directory: %s" % dir_snr)
    
    for snr in SNRs:
        dir_snr = Path("./Results/Noisy/k-Fold Stability/{}/{}".format(noise, snr))
        dir_snr.mkdir(parents=True, exist_ok=True)
        print("Making Directory: %s" % dir_snr)
        

        IHC_test_accuracies={}
        
        #Reload any old results so that we can continue training if required. 
        test_location='Results/Noisy/k-Fold Stability/{}/{}/IHC_models.pkl'.format(noise, snr)

        if(Path(test_location).is_file()):
            with open(test_location, 'rb') as f:
                IHC_test_accuracies = pickle.load(f)
            
        for model in IHC_models:
            print("=============================")
            print("Starting Noisy k-Fold Model Testing for: %s for %s noise at an SNR of %d" %(model, noise, snr))
            
            for k in range(5):
                
            
                #Test the model on the noisy dataset
                test_accu, test_loss, unique_phonemes, time=TrainEvalFunctions.test_best(model, distributed=False, Kfold_eval=True, kInt=k,  noise=True , noise_type= noise, SNR= snr)

                IHC_test_accuracies["{}-kFold-{}".format(model, k+1)]=test_accu

            print("==============================")
            print("")
            print("")

        #Saved for every SNR
        with open(test_location, 'wb') as f:
            pickle.dump(IHC_test_accuracies, f)
# Out:
# Making Directory: Results/Noisy/k-Fold Stability
# Making Directory: Results/Noisy/k-Fold Stability/White
# Making Directory: Results/Noisy/k-Fold Stability/White/30
# =============================
# Starting Noisy k-Fold Model Testing for: IHC_Extract_3.0 for White noise at an SNR of 30
# > Initialising model: IHC_Extract_3.0
# **************************************************************
# Testing Best Model found at: Model Checkpoints/IHC_Extract_3.0 Checkpoints/kFold Eval 0/best_IHC_Extract_3.0_checkpoint.pth.tar
# **************************************************************
# > Initialising model: IHC_Extract_3.0
# > Setting: Test Mode
# Loading model checkpoint
# +---------------------------------------------+
# Using Test Data. Test Accuracy :
# Testing For: | Batchsize 4 | Steps: 237
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 36
#      30 print("Starting Noisy k-Fold Model Testing for: %s for %s noise at an SNR of %d" %(model, noise, snr))
#      32 for k in range(5):
#      33
#      34
#      35     #Test the model on the noisy dataset
# ---> 36     test_accu, test_loss, unique_phonemes, time=TrainEvalFunctions.test_best(model, distributed=False, Kfold_eval=True, kInt=k,  noise=True , noise_type= noise, SNR= snr)
#      38     IHC_test_accuracies["{}-kFold-{}".format(model, k+1)]=test_accu
#      40 print("==============================")
#
# File ~/work/Phoneme Discrimination/Train_TestFunctions/TrainEvalFunctions.py:210, in test_best(model_name, learning_rate, distributed, Kfold_eval, kInt, noise, noise_type, SNR)
#     208 print("+---------------------------------------------+")
#     209 print("Using Test Data. Test Accuracy :")
# --> 210 test_accu, test_loss, class_correct, class_total, time, confusion= evaluate(model, Testloader, device=device)
#     211 print("+---------------------------------------------+")
#     213 #Turn the confusion matrix into a dataframe
#
# File ~/work/Phoneme Discrimination/Train_TestFunctions/Serial_train.py:152, in evaluate(model, valid_data, num_classes, device)
#     150 #Get the class labels
#     151 loss = torch.nn.CrossEntropyLoss()(outputs, phonemes)
# --> 152 val_losses.append(loss.item())
#     154 #Get the longest length of phonemes
#     155 target=torch.argmax(phonemes.data, 1)
#
# KeyboardInterrupt:
